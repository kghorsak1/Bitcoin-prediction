# %%
import yfinance as yf
import pandas as pd
import plotly.express as px

# Define the tickers
tickers = {
    'Bitcoin': 'btc-USD',
}

# Download historical data for the tickers
data = yf.download(
    tickers=list(tickers.values()),
    period='max',       # Adjust the period as needed # Adjust the period as needed '6mo' '1d' 'max'
    interval='1d',     # Data interval Data interval '1m' '1h' '1d'       #best is w max and 1d so far 
    group_by='ticker',
    auto_adjust=True,
    threads=True
)

print(data)

btc = data


#Only for my pc

#Flattening the multi-level columns
btc.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in btc.columns]

# Renaming the columns to remove prefixes and simplify names
new_column_names = {
    'Date': 'Date',
    'BTC-USD_Open': 'Open',
    'BTC-USD_High': 'High',
    'BTC-USD_Low': 'Low',
    'BTC-USD_Close': 'Close',
    'BTC-USD_Volume': 'Volume'
}
btc.rename(columns=new_column_names, inplace=True)

# Reset the index, which moves the date from the index to a column
btc.reset_index(inplace=True)

# Step 1: Extract Bitcoin Volume before dropping columns
print(btc['Volume'].eq(0).sum())
print(btc)
print(btc.describe())
na_counts = btc.isna().sum()

# Display the count of NaNs for each column
print(na_counts)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker                           BTC-USD                               \
# Price                               Open           High           Low
# Date
# 2014-09-17 00:00:00+00:00     465.864014     468.174011    452.421997
# 2014-09-18 00:00:00+00:00     456.859985     456.859985    413.104004
# 2014-09-19 00:00:00+00:00     424.102997     427.834991    384.532013
# 2014-09-20 00:00:00+00:00     394.673004     423.295990    389.882996
# 2014-09-21 00:00:00+00:00     408.084991     412.425995    393.181000
# ...                                  ...            ...           ...
# 2024-12-06 00:00:00+00:00   97074.226562  102039.882812  96514.875000
# 2024-12-07 00:00:00+00:00   99916.710938  100563.382812  99030.882812
# 2024-12-08 00:00:00+00:00   99921.914062  101399.992188  98771.515625
# 2024-12-09 00:00:00+00:00  101237.062500  101272.507812  94355.914062
# 2024-12-10 00:00:00+00:00   97391.328125   98220.039062  94435.835938
#
# Ticker
# Price                              Close        Volume
# Date
# 2014-09-17 00:00:00+00:00     457.334015      21056800
# 2014-09-18 00:00:00+00:00     424.440002      34483200
# 2014-09-19 00:00:00+00:00     394.795990      37919700
# 2014-09-20 00:00:00+00:00     408.903992      36863600
# 2014-09-21 00:00:00+00:00     398.821014      26580100
# ...                                  ...           ...
# 2024-12-06 00:00:00+00:00   99920.710938   94534772658
# 2024-12-07 00:00:00+00:00   99923.335938   44177510897
# 2024-12-08 00:00:00+00:00  101236.015625   44125751925
# 2024-12-09 00:00:00+00:00   97432.718750  110676473908
# 2024-12-10 00:00:00+00:00   96118.421875  120592867328
#
# [3738 rows x 5 columns]
# 0
#                           Date           Open           High           Low  \
# 0    2014-09-17 00:00:00+00:00     465.864014     468.174011    452.421997
# 1    2014-09-18 00:00:00+00:00     456.859985     456.859985    413.104004
# 2    2014-09-19 00:00:00+00:00     424.102997     427.834991    384.532013
# 3    2014-09-20 00:00:00+00:00     394.673004     423.295990    389.882996
# 4    2014-09-21 00:00:00+00:00     408.084991     412.425995    393.181000
# ...                        ...            ...            ...           ...
# 3733 2024-12-06 00:00:00+00:00   97074.226562  102039.882812  96514.875000
# 3734 2024-12-07 00:00:00+00:00   99916.710938  100563.382812  99030.882812
# 3735 2024-12-08 00:00:00+00:00   99921.914062  101399.992188  98771.515625
# 3736 2024-12-09 00:00:00+00:00  101237.062500  101272.507812  94355.914062
# 3737 2024-12-10 00:00:00+00:00   97391.328125   98220.039062  94435.835938
#
#               Close        Volume
# 0        457.334015      21056800
# 1        424.440002      34483200
# 2        394.795990      37919700
# 3        408.903992      36863600
# 4        398.821014      26580100
# ...             ...           ...
# 3733   99920.710938   94534772658
# 3734   99923.335938   44177510897
# 3735  101236.015625   44125751925
# 3736   97432.718750  110676473908
# 3737   96118.421875  120592867328
#
# [3738 rows x 6 columns]
#                 Open           High           Low          Close        Volume
# count    3738.000000    3738.000000   3738.000000    3738.000000  3.738000e+03
# mean    19118.863693   19551.445274  18668.838942   19143.167514  1.835552e+10
# std     21348.439828   21824.165744  20861.137244   21381.252327  2.011095e+10
# min       176.897003     211.731003    171.509995     178.102997  5.914570e+06
# 25%      1209.992493    1232.170013   1194.517517    1210.635040  3.693400e+08
# 50%      9322.738770    9473.759766   9165.256836    9323.249512  1.449977e+10
# 75%     30314.762207   30782.770996  29739.608398   30322.416016  2.936403e+10
# max    101237.062500  103900.468750  99030.882812  101236.015625  3.509679e+11
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
if 'Datetime' in btc.columns:
    btc.rename(columns={'Datetime': 'Date'}, inplace=True)
    btc = btc.drop(columns="Volume")

print(btc)

# Perform min-max normalization for each asset
normalized_prices = btc.copy()

# Exclude the 'Date' column during normalization
for col in normalized_prices.columns[1:]:
    min_price = normalized_prices[col].min()
    max_price = normalized_prices[col].max()
    normalized_prices[col] = ((normalized_prices[col] - min_price) / (max_price - min_price)) * 100

# Melt the DataFrame to long format
normalized_prices_melted = normalized_prices.melt(id_vars='Date', var_name='Asset', value_name='Normalized Price')

import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot each asset's normalized prices
for asset, data in normalized_prices_melted.groupby('Asset'):
    ax.plot(data['Date'], data['Normalized Price'], label=asset)

# Set labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Normalized Price (0% = Min, 100% = Max)')
ax.set_title('Min-Max Normalized Closing Prices for Selected Assets Over Time')
ax.legend()

# Show the plot
plt.show()

btc.rename(columns={'Close': 'Bitcoin Close'}, inplace=True)
print(btc)

# %%
import pandas as pd
import os

def clean_sentiment_score(score):
    """Remove leading single quote from sentiment score if present"""
    if isinstance(score, str) and score.startswith("'"):
        return float(score.lstrip("'"))
    return float(score)

# Read the sentiment file
file_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'combined_crypto_analysis.csv')
sentiment_df = pd.read_csv(file_path)

# Process and merge the data
sentiment_df['Date'] = pd.to_datetime(sentiment_df['Date']).dt.tz_localize('UTC')
sentiment_df['sentiment_score'] = sentiment_df['avg_sentiment'].apply(clean_sentiment_score)
btc['Date'] = pd.to_datetime(btc['Date'])

# Merge and update btc DataFrame
btc = btc.merge(sentiment_df[['Date', 'sentiment_score']], on='Date', how='left')

print(f"Merged shape: {btc.shape}, Rows with sentiment: {btc['sentiment_score'].notna().sum()}")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Converts Close to Percentage ################################################################################
btc["Close"] = btc['Bitcoin Close']
btc['Bitcoin Close'] = btc['Bitcoin Close'].pct_change() * 100
btc = btc.dropna().reset_index(drop=True)

#rescaled_data.dropna(inplace=True) 

def global_rescale(data):
    mean_val = np.mean(data)
    std_val = np.std(data)
    # Avoid division by zero if data has zero variance
    if std_val == 0:
        rescaled_data = np.zeros_like(data)
    else:
        rescaled_data = (data - mean_val) / std_val
    return rescaled_data

if 'Date' in btc.columns:
    btc = btc.drop(columns='Date')
# Apply the global_rescale function to each column
rescaled_data = btc.apply(global_rescale) 

print("btc")
print(btc)
print("rescaled_data")
print(rescaled_data)

# Calculate EMA for ATR
def calculate_ema(series, length):
    return series.ewm(span=length, adjust=False).mean()

# Parameters
bb_length = 20
bb_std_dev = 2
kc_length = 20
kc_multiplier = 1.5

# Convert percentage changes back to price-like series for calculations
cumulative_returns = btc['Close']
cumulative_high = btc['High']
cumulative_low = btc['Low']

# Calculate Bollinger Bands on the cumulative series
sma = cumulative_returns.rolling(window=bb_length).mean()
std = cumulative_returns.rolling(window=bb_length).std()
bb_upper = sma + (bb_std_dev * std)
bb_lower = sma - (bb_std_dev * std)

# Calculate True Range using cumulative values
tr1 = cumulative_high - cumulative_low
tr2 = abs(cumulative_high - cumulative_returns.shift(1))
tr3 = abs(cumulative_low - cumulative_returns.shift(1))
true_range = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)

# Calculate ATR using EMA
atr = calculate_ema(true_range, kc_length)

# Calculate Keltner Channels
kc_upper = sma + (kc_multiplier * atr)
kc_lower = sma - (kc_multiplier * atr)

# Calculate TTM Squeeze
squeeze = np.where(
    (bb_upper < kc_upper) & (bb_lower > kc_lower),
    1,  # Squeeze is on
    0   # Squeeze is off
)

# Calculate Momentum
highest_high = cumulative_high.rolling(window=bb_length).max()
lowest_low = cumulative_low.rolling(window=bb_length).min()
avg_hl = (highest_high + lowest_low) / 2
avg_hlc = (avg_hl + cumulative_returns) / 2
momentum = cumulative_returns - avg_hlc

# Store calculations
btc['squeeze'] = squeeze
rescaled_data['squeeze'] = squeeze
btc['momentum'] = momentum
btc['BB_upper'] = bb_upper
btc['BB_lower'] = bb_lower
btc['KC_upper'] = kc_upper
btc['KC_lower'] = kc_lower
btc['BB_width'] = bb_upper - bb_lower
btc['KC_width'] = kc_upper - kc_lower
btc['BB_KC_ratio'] = (bb_upper - bb_lower) / (kc_upper - kc_lower)

# Print statistics
print("\nBand Width Statistics:")
print("\nBollinger Band Width:")
print(btc['BB_width'].describe())
print("\nKeltner Channel Width:")
print(btc['KC_width'].describe())
print("\nSqueeze Statistics:")
print(f"Total periods: {len(btc)}")
print(f"Number of squeeze periods: {btc['squeeze'].sum()}")
print(f"Percentage of time in squeeze: {(btc['squeeze'].sum() / len(btc) * 100):.2f}%")

# Visualization
plt.figure(figsize=(15, 10))

# Plot 1: Price with squeeze points
plt.subplot(2, 1, 1)
plt.plot(btc.index, cumulative_returns, label='Cumulative Returns', alpha=0.7)
squeeze_points = btc[btc['squeeze'] == 1].index
plt.scatter(squeeze_points, 
           cumulative_returns[squeeze_points],
           color='red', marker='^', label='Squeeze')
plt.title('Cumulative Returns with Squeeze Points')
plt.legend()

# Plot 2: BB/KC Width Ratio
plt.subplot(2, 1, 2)
plt.plot(btc.index, btc['BB_KC_ratio'], label='BB/KC Width Ratio')
plt.axhline(y=1, color='r', linestyle='--', label='Squeeze Threshold')
plt.title('Bollinger Bands to Keltner Channel Width Ratio')
plt.legend()

plt.tight_layout()
plt.show()

print(btc['BB_width'].describe())
print(btc['KC_width'].describe())
print(btc['BB_KC_ratio'].describe())

# Print initial values to check scales and consistency
print("First few values of cumulative_returns:")
print(cumulative_returns.tail())

print("First few values of cumulative_high:")
print(cumulative_high.tail())

print("First few values of cumulative_low:")
print(cumulative_low.tail())

# After calculating True Range and ATR
print("\nFirst few values of True Range (TR):")
print(tr1.tail(), tr2.tail(), tr3.tail())

print("\nFirst few values of Average True Range (ATR):")
print(atr.tail())

# After calculating Bollinger Bands
print("\nFirst few values of SMA for Bollinger Bands:")
print(sma.tail())

print("\nFirst few values of Bollinger Bands Upper and Lower:")
print("BB Upper:", bb_upper.tail())
print("BB Lower:", bb_lower.tail())

# After calculating Keltner Channels
print("\nFirst few values of Keltner Channels Upper and Lower:")
print("KC Upper:", kc_upper.tail())
print("KC Lower:", kc_lower.tail())

# After calculating Widths
print("\nBollinger Band Width:")
print(btc['BB_width'].tail())

print("\nKeltner Channel Width:")
print(btc['KC_width'].tail())

# Print ratios and squeeze information
print("\nFirst few values of BB/KC Width Ratio:")
print(btc['BB_KC_ratio'].tail())

print("\nSqueeze Statistics:")
print("First few periods of squeeze signal:")
print(btc['squeeze'].tail())


btc.drop(columns=['Close'], inplace=True)

# Calculate EMAs and SMAs on the raw price data
price_emas = {
    'EMA_9': btc['Bitcoin Close'].ewm(span=9, adjust=False).mean(),
    'EMA_12': btc['Bitcoin Close'].ewm(span=12, adjust=False).mean(),
    'EMA_26': btc['Bitcoin Close'].ewm(span=26, adjust=False).mean(),
    'SMA_50': btc['Bitcoin Close'].rolling(window=50).mean(),
    'SMA_100': btc['Bitcoin Close'].rolling(window=100).mean(),
    'SMA_200': btc['Bitcoin Close'].rolling(window=200).mean()
}

# Calculate percentage-based EMAs and SMAs
rescaled_data['EMA_9'] = btc['Bitcoin Close'].ewm(span=9, adjust=False).mean()
rescaled_data['EMA_12'] = btc['Bitcoin Close'].ewm(span=12, adjust=False).mean()
rescaled_data['EMA_26'] = btc['Bitcoin Close'].ewm(span=26, adjust=False).mean()
rescaled_data['SMA_50'] = btc['Bitcoin Close'].rolling(window=50).mean()
rescaled_data['SMA_100'] = btc['Bitcoin Close'].rolling(window=100).mean()
rescaled_data['SMA_200'] = btc['Bitcoin Close'].rolling(window=200).mean()

# Detect upward crossovers
rescaled_data['Cross_9_12_Up'] = ((rescaled_data['EMA_9'] > rescaled_data['EMA_12']) & (rescaled_data['EMA_9'].shift(1) <= rescaled_data['EMA_12'].shift(1))).astype(int)
rescaled_data['Cross_9_26_Up'] = ((rescaled_data['EMA_9'] > rescaled_data['EMA_26']) & (rescaled_data['EMA_9'].shift(1) <= rescaled_data['EMA_26'].shift(1))).astype(int)
rescaled_data['Cross_12_26_Up'] = ((rescaled_data['EMA_12'] > rescaled_data['EMA_26']) & (rescaled_data['EMA_12'].shift(1) <= rescaled_data['EMA_26'].shift(1))).astype(int)

# Detect downward crossovers
rescaled_data['Cross_9_12_Down'] = ((rescaled_data['EMA_9'] < rescaled_data['EMA_12']) & (rescaled_data['EMA_9'].shift(1) >= rescaled_data['EMA_12'].shift(1))).astype(int)
rescaled_data['Cross_9_26_Down'] = ((rescaled_data['EMA_9'] < rescaled_data['EMA_26']) & (rescaled_data['EMA_9'].shift(1) >= rescaled_data['EMA_26'].shift(1))).astype(int)
rescaled_data['Cross_12_26_Down'] = ((rescaled_data['EMA_12'] < rescaled_data['EMA_26']) & (rescaled_data['EMA_12'].shift(1) >= rescaled_data['EMA_26'].shift(1))).astype(int)

# Drop all NaN values and reset index
rescaled_data.dropna(inplace=True)
rescaled_data.reset_index(drop=True, inplace=True)

print("Rescaled Data:")
print(rescaled_data)

# Compute basic statistics for each column
stats = rescaled_data.describe()

# Print the statistics
print("\nBasic Statistical Summary:")
print(stats)

# Plot violin plots for each column
plt.figure(figsize=(12, 8))
sns.violinplot(data=rescaled_data)
plt.title('Violin Plots of Rescaled Data')
plt.xticks(rotation=45)
plt.show()

# Compute the correlation matrix
corr_matrix = rescaled_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Plot histograms with a standard normal distribution overlay for each column
fig, axes = plt.subplots(nrows=len(rescaled_data.columns), ncols=1, figsize=(10, 5 * len(rescaled_data.columns)))
if len(rescaled_data.columns) == 1:
    axes = [axes]  # Ensure axes is iterable for a single-column dataframe

for ax, column in zip(axes, rescaled_data.columns):
    data = rescaled_data[column].dropna()  # Drop NA values

    # Define the number of bins to make them smaller
    bins = 200

    # Plot histogram
    ax.hist(data, bins=bins, density=True, alpha=0.6, color='g')
    
    # Define the range of x values for the normal distribution line
    xmin, xmax = ax.get_xlim()
    x = np.linspace(xmin, xmax, 100)
    
    # Calculate the standard normal distribution
    p = norm.pdf(x, 0, 1)  # Mean = 0, Std = 1
    ax.plot(x, p, 'k', linewidth=2)
    
    ax.set_title(f"Standard Normal Distribution Overlay")
    ax.set_xlabel(column)
    ax.set_ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# btc
#               Open          High           Low  Bitcoin Close       Volume  \
# 0       456.859985    456.859985    413.104004      -7.192558     34483200
# 1       424.102997    427.834991    384.532013      -6.984265     37919700
# 2       394.673004    423.295990    389.882996       3.573492     36863600
# 3       408.084991    412.425995    393.181000      -2.465854     26580100
# 4       399.100006    406.915985    397.130005       0.835210     24127600
# ...            ...           ...           ...            ...          ...
# 3723  91978.140625  97361.179688  91778.664062       4.323745  71133452438
# 3724  95954.945312  96650.203125  94677.351562      -0.323108  52260008261
# 3725  95653.953125  98693.171875  95407.882812       1.891279  54968682476
# 3726  97468.812500  97499.343750  96144.218750      -1.038839  31634227866
# 3727  96461.335938  97888.125000  95770.187500       0.861319  36590695296
#
#       sentiment_score         Close
# 0           -2.274216    424.440002
# 1           -1.657459    394.795990
# 2           -1.755881    408.903992
# 3           -1.755881    398.821014
# 4           -2.158273    402.152008
# ...               ...           ...
# 3723        -1.302057  95962.531250
# 3724        -0.375339  95652.468750
# 3725         0.467415  97461.523438
# 3726         1.842708  96449.054688
# 3727         1.002571  97279.789062
#
# [3728 rows x 7 columns]
# rescaled_data
#           Open      High       Low  Bitcoin Close    Volume  sentiment_score  \
# 0    -0.879182 -0.879903 -0.879988      -2.040219 -0.918021        -0.763469
# 1    -0.880740 -0.881254 -0.881379      -1.982813 -0.917847        -0.300927
# 2    -0.882141 -0.881465 -0.881119       0.926918 -0.917901        -0.374739
# 3    -0.881502 -0.881971 -0.880958      -0.737534 -0.918420        -0.374739
# 4    -0.881930 -0.882228 -0.880766       0.172244 -0.918544        -0.676517
# ...        ...       ...       ...            ...       ...              ...
# 3723  3.475817  3.630306  3.568038       1.133688  2.675969        -0.034390
# 3724  3.665051  3.597215  3.709157      -0.146990  1.721933         0.660611
# 3725  3.650729  3.692301  3.744722       0.463298  1.858855         1.292642
# 3726  3.737088  3.636736  3.780570      -0.344247  0.679318         2.324055
# 3727  3.689148  3.654831  3.762361       0.179440  0.929863         1.693987
#
#          Close
# 0    -0.880431
# 1    -0.881839
# 2    -0.881169
# 3    -0.881648
# 4    -0.881490
# ...        ...
# 3723  3.658114
# 3724  3.643385
# 3725  3.729324
# 3726  3.681226
# 3727  3.720691
#
# [3728 rows x 7 columns]
#
# Band Width Statistics:
#
# Bollinger Band Width:
# count     3709.000000
# mean      4297.664753
# std       5582.674845
# min         10.679233
# 25%        319.551435
# 50%       2065.746485
# 75%       6488.964456
# max      39268.288731
# Name: BB_width, dtype: float64
#
# Keltner Channel Width:
# count     3709.000000
# mean      2609.823380
# std       3135.504471
# min          9.846689
# 25%        187.898466
# 50%       1155.763658
# 75%       4109.488691
# max      16079.761631
# Name: KC_width, dtype: float64
#
# Squeeze Statistics:
# Total periods: 3728
# Number of squeeze periods: 415
# Percentage of time in squeeze: 11.13%
# count     3709.000000
# mean      4297.664753
# std       5582.674845
# min         10.679233
# 25%        319.551435
# 50%       2065.746485
# 75%       6488.964456
# max      39268.288731
# Name: BB_width, dtype: float64
# count     3709.000000
# mean      2609.823380
# std       3135.504471
# min          9.846689
# 25%        187.898466
# 50%       1155.763658
# 75%       4109.488691
# max      16079.761631
# Name: KC_width, dtype: float64
# count    3709.000000
# mean        1.754004
# std         0.721469
# min         0.473087
# 25%         1.187568
# 50%         1.606496
# 75%         2.174062
# max         4.776663
# Name: BB_KC_ratio, dtype: float64
# First few values of cumulative_returns:
# 3723    95962.531250
# 3724    95652.468750
# 3725    97461.523438
# 3726    96449.054688
# 3727    97279.789062
# Name: Close, dtype: float64
# First few values of cumulative_high:
# 3723    97361.179688
# 3724    96650.203125
# 3725    98693.171875
# 3726    97499.343750
# 3727    97888.125000
# Name: High, dtype: float64
# First few values of cumulative_low:
# 3723    91778.664062
# 3724    94677.351562
# 3725    95407.882812
# 3726    96144.218750
# 3727    95770.187500
# Name: Low, dtype: float64
#
# First few values of True Range (TR):
# 3723    5582.515625
# 3724    1972.851562
# 3725    3285.289062
# 3726    1355.125000
# 3727    2117.937500
# dtype: float64 3723    5375.859375
# 3724     687.671875
# 3725    3040.703125
# 3726      37.820312
# 3727    1439.070312
# dtype: float64 3723     206.656250
# 3724    1285.179688
# 3725     244.585938
# 3726    1317.304688
# 3727     678.867188
# dtype: float64
#
# First few values of Average True Range (ATR):
# 3723    3879.614141
# 3724    3698.017705
# 3725    3658.710215
# 3726    3439.321147
# 3727    3313.475086
# dtype: float64
#
# First few values of SMA for Bollinger Bands:
# 3723    90566.516016
# 3724    91521.865625
# 3725    92555.998438
# 3726    93354.741797
# 3727    93783.657031
# Name: Close, dtype: float64
#
# First few values of Bollinger Bands Upper and Lower:
# BB Upper: 3723    103601.815315
# 3724    102929.516728
# 3725    101899.431944
# 3726    100909.450658
# 3727    101198.770321
# Name: Close, dtype: float64
# BB Lower: 3723    77531.216716
# 3724    80114.214522
# 3725    83212.564931
# 3726    85800.032936
# 3727    86368.543741
# Name: Close, dtype: float64
#
# First few values of Keltner Channels Upper and Lower:
# KC Upper: 3723    96385.937227
# 3724    97068.892183
# 3725    98044.063761
# 3726    98513.723518
# 3727    98753.869660
# dtype: float64
# KC Lower: 3723    84747.094804
# 3724    85974.839067
# 3725    87067.933114
# 3726    88195.760076
# 3727    88813.444403
# dtype: float64
#
# Bollinger Band Width:
# 3723    26070.598599
# 3724    22815.302206
# 3725    18686.867013
# 3726    15109.417722
# 3727    14830.226580
# Name: BB_width, dtype: float64
#
# Keltner Channel Width:
# 3723    11638.842424
# 3724    11094.053115
# 3725    10976.130646
# 3726    10317.963442
# 3727     9940.425257
# Name: KC_width, dtype: float64
#
# First few values of BB/KC Width Ratio:
# 3723    2.239965
# 3724    2.056534
# 3725    1.702500
# 3726    1.464380
# 3727    1.491911
# Name: BB_KC_ratio, dtype: float64
#
# Squeeze Statistics:
# First few periods of squeeze signal:
# 3723    0
# 3724    0
# 3725    0
# 3726    0
# 3727    0
# Name: squeeze, dtype: int64
# Rescaled Data:
#           Open      High       Low  Bitcoin Close    Volume  sentiment_score  \
# 0    -0.888846 -0.889034 -0.887834       0.691741 -0.918771        -0.335174
# 1    -0.888515 -0.888982 -0.887706      -0.597936 -0.918751         0.408376
# 2    -0.888774 -0.889261 -0.887821      -0.307340 -0.918831        -1.008563
# 3    -0.888879 -0.889352 -0.888210      -0.945986 -0.918243         0.679519
# 4    -0.889275 -0.889712 -0.888445      -0.209340 -0.918670         0.612577
# ...        ...       ...       ...            ...       ...              ...
# 3524  3.475817  3.630306  3.568038       1.133688  2.675969        -0.034390
# 3525  3.665051  3.597215  3.709157      -0.146990  1.721933         0.660611
# 3526  3.650729  3.692301  3.744722       0.463298  1.858855         1.292642
# 3527  3.737088  3.636736  3.780570      -0.344247  0.679318         2.324055
# 3528  3.689148  3.654831  3.762361       0.179440  0.929863         1.693987
#
#          Close  squeeze     EMA_9    EMA_12    EMA_26    SMA_50   SMA_100  \
# 0    -0.888214        0  0.728791  0.512271  0.161655  0.077749 -0.104078
# 1    -0.888457        0  0.191166  0.132024  0.004545  0.213410 -0.086891
# 2    -0.888567        0 -0.028053 -0.027506 -0.062823  0.203675 -0.100297
# 3    -0.888954        0 -0.666884 -0.518999 -0.296852  0.055696 -0.118117
# 4    -0.889018        0 -0.643375 -0.523667 -0.315555  0.104510 -0.117428
# ...        ...      ...       ...       ...       ...       ...       ...
# 3524  3.658114        0  0.512264  0.605204  0.856558  0.912650  0.512678
# 3525  3.643385        0  0.345190  0.462387  0.769176  0.956077  0.517526
# 3526  3.729324        0  0.654407  0.682216  0.852294  1.004057  0.499796
# 3527  3.681226        0  0.315758  0.417439  0.712210  0.911257  0.502375
# 3528  3.720691        0  0.424870  0.485728  0.723256  0.904529  0.449506
#
#        SMA_200  Cross_9_12_Up  Cross_9_26_Up  Cross_12_26_Up  Cross_9_12_Down  \
# 0    -0.189640              0              0               0                0
# 1    -0.163474              0              0               0                0
# 2    -0.133077              0              0               0                1
# 3    -0.167056              0              0               0                0
# 4    -0.157473              0              0               0                0
# ...        ...            ...            ...             ...              ...
# 3524  0.264024              0              0               0                0
# 3525  0.257024              0              0               0                0
# 3526  0.254657              0              0               0                0
# 3527  0.260183              0              0               0                0
# 3528  0.226192              0              0               0                0
#
#       Cross_9_26_Down  Cross_12_26_Down
# 0                   0                 0
# 1                   0                 0
# 2                   0                 0
# 3                   1                 1
# 4                   0                 0
# ...               ...               ...
# 3524                0                 0
# 3525                0                 0
# 3526                0                 0
# 3527                0                 0
# 3528                0                 0
#
# [3529 rows x 20 columns]
#
# Basic Statistical Summary:
#               Open         High          Low  Bitcoin Close       Volume  \
# count  3529.000000  3529.000000  3529.000000    3529.000000  3529.000000
# mean      0.049968     0.049980     0.049925       0.006442     0.051789
# std       1.004938     1.004928     1.004978       0.989517     1.003210
# min      -0.890925    -0.890749    -0.890384     -10.301911    -0.919228
# 25%      -0.732245    -0.732864    -0.732046      -0.390469    -0.829759
# 50%      -0.430418    -0.428558    -0.429657      -0.019432    -0.112416
# 75%       0.635384     0.651550     0.614000       0.400268     0.610694
# max       3.810270     3.737090     3.833571       6.900209    16.821357
#
#        sentiment_score        Close      squeeze        EMA_9       EMA_12  \
# count      3529.000000  3529.000000  3529.000000  3529.000000  3529.000000
# mean          0.049551     0.049954     0.113913     0.233389     0.233024
# std           0.858040     1.004952     0.317751     1.217298     1.065241
# min          -5.271848    -0.890594     0.000000    -8.456211    -6.724149
# 25%          -0.443834    -0.731811     0.000000    -0.380663    -0.308373
# 50%           0.107457    -0.430796     0.000000     0.158584     0.150691
# 75%           0.599414     0.633316     0.000000     0.845061     0.763458
# max           3.387060     3.802298     1.000000     9.973223     8.400091
#
#             EMA_26       SMA_50      SMA_100      SMA_200  Cross_9_12_Up  \
# count  3529.000000  3529.000000  3529.000000  3529.000000    3529.000000
# mean      0.230895     0.227071     0.224613     0.219281       0.119014
# std       0.751508     0.569751     0.431303     0.324891       0.323851
# min      -3.513003    -1.757192    -0.800688    -0.480130       0.000000
# 25%      -0.189013    -0.141131    -0.051375     0.007513       0.000000
# 50%       0.161879     0.168759     0.175459     0.215399       0.000000
# 75%       0.615025     0.575305     0.480318     0.378338       0.000000
# max       5.242872     2.641750     1.707500     1.244464       1.000000
#
#        Cross_9_26_Up  Cross_12_26_Up  Cross_9_12_Down  Cross_9_26_Down  \
# count    3529.000000     3529.000000      3529.000000      3529.000000
# mean        0.098612        0.088694         0.119297         0.098895
# std         0.298182        0.284341         0.324184         0.298563
# min         0.000000        0.000000         0.000000         0.000000
# 25%         0.000000        0.000000         0.000000         0.000000
# 50%         0.000000        0.000000         0.000000         0.000000
# 75%         0.000000        0.000000         0.000000         0.000000
# max         1.000000        1.000000         1.000000         1.000000
#
#        Cross_12_26_Down
# count       3529.000000
# mean           0.088977
# std            0.284751
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit, train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, roc_curve, auc, RocCurveDisplay, ConfusionMatrixDisplay, accuracy_score, classification_report
from skorch import NeuralNetRegressor
from skorch.callbacks import EarlyStopping, LRScheduler, Callback
from skorch.dataset import Dataset
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# First, create the train-test split (keeping the most recent data for testing)
test_size = 0.2
val_size = 0.2  
eval_size = 0.1 

# Calculate split indices
total_size = len(rescaled_data)
test_split_idx = int(total_size * (1 - test_size))
val_split_idx = int(test_split_idx * (1 - val_size - eval_size))
eval_split_idx = int(test_split_idx * (1 - eval_size))

# Split the data
X_train = rescaled_data.iloc[:val_split_idx, :]
X_eval = rescaled_data.iloc[val_split_idx:eval_split_idx, :]
X_val = rescaled_data.iloc[eval_split_idx:test_split_idx, :]
X_test = rescaled_data.iloc[test_split_idx:, :]

y_train = rescaled_data['Bitcoin Close'][:val_split_idx]
y_eval = rescaled_data['Bitcoin Close'][val_split_idx:eval_split_idx]
y_val = rescaled_data['Bitcoin Close'][eval_split_idx:test_split_idx]
y_test = rescaled_data['Bitcoin Close'][test_split_idx:]

def create_sequences(data, target, seq_length=10):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data.iloc[i:(i + seq_length)].to_numpy())
        y.append(target.iloc[i + seq_length])
    return np.array(X), np.array(y)

# Create sequences for all splits
seq_length = 10
X_train_seq, y_train_seq = create_sequences(X_train, y_train, seq_length)
X_eval_seq, y_eval_seq = create_sequences(X_eval, y_eval, seq_length)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, seq_length)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, seq_length)

# Convert to torch tensors
X_train_seq = torch.tensor(X_train_seq, dtype=torch.float32)
y_train_seq = torch.tensor(y_train_seq, dtype=torch.float32).reshape(-1, 1)
X_eval_seq = torch.tensor(X_eval_seq, dtype=torch.float32)
y_eval_seq = torch.tensor(y_eval_seq, dtype=torch.float32).reshape(-1, 1)
X_val_seq = torch.tensor(X_val_seq, dtype=torch.float32)
y_val_seq = torch.tensor(y_val_seq, dtype=torch.float32).reshape(-1, 1)
X_test_seq = torch.tensor(X_test_seq, dtype=torch.float32)
y_test_seq = torch.tensor(y_test_seq, dtype=torch.float32).reshape(-1, 1)

# Combine training and evaluation sets
X_combined = torch.cat([X_train_seq, X_eval_seq])
y_combined = torch.cat([y_train_seq, y_eval_seq])

# Create proper skorch Dataset
train_dataset = Dataset(X_combined, y_combined)

class PrintLossCallback(Callback):
    def on_epoch_end(self, net, dataset_train=None, dataset_valid=None, **kwargs):
        train_loss = net.history[-1, 'train_loss']
        valid_loss = net.history[-1, 'valid_loss']
        epoch = len(net.history)
        print(f'Epoch: {epoch:4d} | Train Loss: {train_loss:.6f} | Valid Loss: {valid_loss:.6f}')

class GradientClippingCallback(Callback):
    def __init__(self, clip_value=1.0):
        self.clip_value = clip_value

    def on_batch_end(self, net, **kwargs):
        torch.nn.utils.clip_grad_norm_(net.module_.parameters(), self.clip_value)

class TimeSeriesValidSplit:
    def __call__(self, dataset, y=None, **kwargs):
        # Using validation data for model validation during training
        train_ds = Dataset(X_train_seq, y_train_seq)
        valid_ds = Dataset(X_val_seq, y_val_seq)
        return train_ds, valid_ds

class MyLSTMModule(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=1, nonlin=nn.ReLU()):
        super().__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(
            input_size=input_size, 
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            batch_first=True,
            bidirectional=False
        )
        
        self.batch_norm = nn.BatchNorm1d(hidden_size)
        self.nonlin = nonlin
        self.fc = nn.Linear(hidden_size, 1)
        
        self.init_weights()

    def init_weights(self):
        for name, param in self.lstm.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0.0)
        nn.init.xavier_uniform_(self.fc.weight, gain=0.1)
        nn.init.constant_(self.fc.bias, 0.0)

    def forward(self, X):
        h0 = torch.zeros(self.num_layers, X.size(0), self.hidden_size).to(X.device)
        c0 = torch.zeros(self.num_layers, X.size(0), self.hidden_size).to(X.device)
        
        out, _ = self.lstm(X, (h0, c0))
        out = out[:, -1, :]
        out = self.batch_norm(out)
        out = self.nonlin(out)
        out = self.fc(out)
        return out

def objective(params):
    """Objective function using simple temporal validation"""
    try:
        net = NeuralNetRegressor(
            MyLSTMModule,
            module__input_size=X_train_seq.shape[2],
            module__hidden_size=int(params['hidden_size']),
            module__num_layers=int(params['num_layers']),
            module__nonlin=params['nonlin'],
            max_epochs=int(params['max_epochs']),
            lr=params['lr'],
            batch_size=int(params['batch_size']),
            optimizer=torch.optim.AdamW,
            optimizer__weight_decay=0.01,
            criterion=torch.nn.MSELoss,
            callbacks=[
                ('print_loss', PrintLossCallback()),
                ('gradient_clipping', GradientClippingCallback(clip_value=0.5)),
                ('lr_scheduler', LRScheduler(
                    policy=ReduceLROnPlateau, 
                    monitor='valid_loss',
                    mode='min',
                    patience=8,
                    factor=0.5,
                    verbose=True
                )),
                ('early_stopping', EarlyStopping(
                    monitor='valid_loss',
                    patience=30,
                    threshold=0.001,
                    threshold_mode='rel',
                    lower_is_better=True
                ))
            ],
            train_split=TimeSeriesValidSplit(),
            verbose=0,
            device='cuda' if torch.cuda.is_available() else 'cpu'
        )
        
        print("\nTraining Started")
        print("-" * 50)
        
        # Train on training data, validate on validation data during training
        net.fit(X_train_seq, y_train_seq)
        
        # Use evaluation set for hyperparameter optimization
        eval_pred = net.predict(X_eval_seq)
        eval_mse = torch.nn.MSELoss()(torch.tensor(eval_pred), y_eval_seq).item()
        
        print(f"Evaluation MSE: {eval_mse:.6f}")
        print("-" * 50)
        
        return {
            'loss': eval_mse,  # Use evaluation set loss for hyperopt
            'status': STATUS_OK,
            'model': net,
            'params': params,
            'eval_score': eval_mse
        }
        
    except Exception as e:
        print(f"Error during training: {str(e)}")
        return {
            'loss': float('inf'),
            'status': STATUS_OK,
            'model': None,
            'params': params
        }

space = {
    'seq_length': hp.choice('seq_length', [5, 10, 15, 20, 30, 50]),
    'hidden_size': hp.choice('hidden_size', [16, 32, 64, 128, 256]),
    'num_layers': hp.choice('num_layers', [1, 2, 3, 4]),
    'dropout_rate': hp.uniform('dropout_rate', 0.05, 0.3),
    'nonlin': hp.choice('nonlin', [nn.ReLU(), nn.Tanh(),nn.LeakyReLU(negative_slope=0.1),nn.GELU()]),
    'max_epochs': hp.choice('max_epochs', [1000]),
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.1)),
    'batch_size': hp.choice('batch_size', [32, 64, 128, 256]),
    'weight_decay': hp.uniform('weight_decay', 0.001, 0.05),
    'use_residual': hp.choice('use_residual', [True, False])
}

# Run the optimization
trials = Trials()
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=50, 
    trials=trials,
    show_progressbar=True
)

# Get the best model and results
best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
best_model = best_trial['result']['model']

print("\n" + "="*50)
print("Optimization Results:")
print("="*50)
print(f"Best evaluation MSE: {best_trial['result']['eval_score']:.4f}")
print("\nBest parameters:")
for param, value in best_trial['result']['params'].items():
    print(f"{param}: {value}")

# Final evaluation on test set (previously unseen data)
test_pred = best_model.predict(X_test_seq)
test_mse = torch.nn.MSELoss()(torch.tensor(test_pred), y_test_seq).item()
print(f"\nFinal Test MSE: {test_mse:.4f}")
# Out:
#
# Training Started
# --------------------------------------------------
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# c:\Users\kghor\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch:    1 | Train Loss: 1.215164 | Valid Loss: 0.945561
# Epoch:    2 | Train Loss: 1.206625 | Valid Loss: 0.832019
# Epoch:    3 | Train Loss: 1.231766 | Valid Loss: 0.964590
# Epoch:    4 | Train Loss: 1.136790 | Valid Loss: 0.813833
# Epoch:    5 | Train Loss: 1.145002 | Valid Loss: 0.988909
# Epoch:    6 | Train Loss: 1.169916 | Valid Loss: 0.989921
# Epoch:    7 | Train Loss: 1.165781 | Valid Loss: 0.917880
# Epoch:    8 | Train Loss: 1.147282 | Valid Loss: 0.843051
# Epoch:    9 | Train Loss: 1.131500 | Valid Loss: 0.853823
# Epoch:   10 | Train Loss: 1.129006 | Valid Loss: 0.834710
# Epoch:   11 | Train Loss: 1.131651 | Valid Loss: 0.840268
# Epoch:   12 | Train Loss: 1.126268 | Valid Loss: 0.835663
# Epoch:   13 | Train Loss: 1.124748 | Valid Loss: 0.836344
# Epoch:   14 | Train Loss: 1.114660 | Valid Loss: 0.841179
# Epoch:   15 | Train Loss: 1.117845 | Valid Loss: 0.851639
# Epoch:   16 | Train Loss: 1.118789 | Valid Loss: 0.847567
# Epoch:   17 | Train Loss: 1.113424 | Valid Loss: 0.840527
# Epoch:   18 | Train Loss: 1.120978 | Valid Loss: 0.824828
# Epoch:   19 | Train Loss: 1.127852 | Valid Loss: 1.101253
# Epoch:   20 | Train Loss: 1.126748 | Valid Loss: 0.817691
# Epoch:   21 | Train Loss: 1.125427 | Valid Loss: 0.833772
# Epoch:   22 | Train Loss: 1.121654 | Valid Loss: 0.843140
# Epoch:   23 | Train Loss: 1.116274 | Valid Loss: 0.848709
# Epoch:   24 | Train Loss: 1.112064 | Valid Loss: 0.881863
# Epoch:   25 | Train Loss: 1.106088 | Valid Loss: 0.877482
# Epoch:   26 | Train Loss: 1.101008 | Valid Loss: 0.923486
# Epoch:   27 | Train Loss: 1.116142 | Valid Loss: 1.029192
# Epoch:   28 | Train Loss: 1.125384 | Valid Loss: 0.955173
# Epoch:   29 | Train Loss: 1.114097 | Valid Loss: 0.841112
# Epoch:   30 | Train Loss: 1.117784 | Valid Loss: 0.806702
# Epoch:   31 | Train Loss: 1.120296 | Valid Loss: 0.886062
# Epoch:   32 | Train Loss: 1.134260 | Valid Loss: 0.876562
# Epoch:   33 | Train Loss: 1.128780 | Valid Loss: 0.994780
# Epoch:   34 | Train Loss: 1.120720 | Valid Loss: 0.871167
# Epoch:   35 | Train Loss: 1.116478 | Valid Loss: 0.887861
# Epoch:   36 | Train Loss: 1.112584 | Valid Loss: 2.330375
# Epoch:   37 | Train Loss: 1.110075 | Valid Loss: 0.889195
# Epoch:   38 | Train Loss: 1.104732 | Valid Loss: 1.192721
# Epoch:   39 | Train Loss: 1.081891 | Valid Loss: 0.982148
# Epoch:   40 | Train Loss: 1.060292 | Valid Loss: 2.904585
# Epoch:   41 | Train Loss: 1.051571 | Valid Loss: 1.465468
# Epoch:   42 | Train Loss: 1.030255 | Valid Loss: 1.311949
# Epoch:   43 | Train Loss: 1.000728 | Valid Loss: 1.110642
# Epoch:   44 | Train Loss: 0.994095 | Valid Loss: 1.662551
# Epoch:   45 | Train Loss: 0.978550 | Valid Loss: 1.239427
# Epoch:   46 | Train Loss: 0.965708 | Valid Loss: 2.198387
# Epoch:   47 | Train Loss: 0.935319 | Valid Loss: 1.558197
# Epoch:   48 | Train Loss: 0.926660 | Valid Loss: 1.814178
# Epoch:   49 | Train Loss: 0.870927 | Valid Loss: 2.098650
# Epoch:   50 | Train Loss: 0.837359 | Valid Loss: 1.695470
# Epoch:   51 | Train Loss: 0.818715 | Valid Loss: 1.765329
# Epoch:   52 | Train Loss: 0.790314 | Valid Loss: 2.310173
# Epoch:   53 | Train Loss: 0.774143 | Valid Loss: 1.938598
# Epoch:   54 | Train Loss: 0.756775 | Valid Loss: 3.185636
# Epoch:   55 | Train Loss: 0.747548 | Valid Loss: 1.740824
# Epoch:   56 | Train Loss: 0.732799 | Valid Loss: 2.876242
# Epoch:   57 | Train Loss: 0.711077 | Valid Loss: 2.341437
# Epoch:   58 | Train Loss: 0.692788 | Valid Loss: 3.138400
# Epoch:   59 | Train Loss: 0.649569 | Valid Loss: 2.176238
# Epoch:   60 | Train Loss: 0.625432 | Valid Loss: 2.642234
# Evaluation MSE: 5.060805
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.156344 | Valid Loss: 0.868496
# Epoch:    2 | Train Loss: 1.129005 | Valid Loss: 0.811463
# Epoch:    3 | Train Loss: 1.129841 | Valid Loss: 0.809777
# Epoch:    4 | Train Loss: 1.129602 | Valid Loss: 0.813413
# Epoch:    5 | Train Loss: 1.129749 | Valid Loss: 0.813069
# Epoch:    6 | Train Loss: 1.130100 | Valid Loss: 0.812765
# Epoch:    7 | Train Loss: 1.130475 | Valid Loss: 0.813022
# Epoch:    8 | Train Loss: 1.130263 | Valid Loss: 0.820543
# Epoch:    9 | Train Loss: 1.129940 | Valid Loss: 0.814317
# Epoch:   10 | Train Loss: 1.131388 | Valid Loss: 0.827183
# Epoch:   11 | Train Loss: 1.129043 | Valid Loss: 0.813990
# Epoch:   12 | Train Loss: 1.130146 | Valid Loss: 0.814480
# Epoch:   13 | Train Loss: 1.129252 | Valid Loss: 0.820002
# Epoch:   14 | Train Loss: 1.129124 | Valid Loss: 0.820964
# Epoch:   15 | Train Loss: 1.129394 | Valid Loss: 0.822356
# Epoch:   16 | Train Loss: 1.128992 | Valid Loss: 0.823317
# Epoch:   17 | Train Loss: 1.128655 | Valid Loss: 0.818530
# Epoch:   18 | Train Loss: 1.128432 | Valid Loss: 0.823732
# Epoch:   19 | Train Loss: 1.128271 | Valid Loss: 4.321583
# Epoch:   20 | Train Loss: 1.128316 | Valid Loss: 10.512587
# Epoch:   21 | Train Loss: 1.127985 | Valid Loss: 0.814133
# Epoch:   22 | Train Loss: 1.126012 | Valid Loss: 0.836271
# Epoch:   23 | Train Loss: 1.125162 | Valid Loss: 0.834845
# Epoch:   24 | Train Loss: 1.125290 | Valid Loss: 0.835109
# Epoch:   25 | Train Loss: 1.125271 | Valid Loss: 0.835052
# Epoch:   26 | Train Loss: 1.125280 | Valid Loss: 0.835052
# Epoch:   27 | Train Loss: 1.125283 | Valid Loss: 0.835043
# Epoch:   28 | Train Loss: 1.125286 | Valid Loss: 0.835034
# Epoch:   29 | Train Loss: 1.125289 | Valid Loss: 0.835027
# Epoch:   30 | Train Loss: 1.125290 | Valid Loss: 0.835019
# Epoch:   31 | Train Loss: 1.124441 | Valid Loss: 0.836018
# Epoch:   32 | Train Loss: 1.124388 | Valid Loss: 0.836451
# Epoch:   33 | Train Loss: 1.124378 | Valid Loss: 0.836358
# Evaluation MSE: 1.164920
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.128847 | Valid Loss: 0.831694
# Epoch:    2 | Train Loss: 1.114800 | Valid Loss: 0.830132
# Epoch:    3 | Train Loss: 1.108842 | Valid Loss: 0.824175
# Epoch:    4 | Train Loss: 1.106435 | Valid Loss: 0.811933
# Epoch:    5 | Train Loss: 1.110297 | Valid Loss: 0.798949
# Epoch:    6 | Train Loss: 1.103089 | Valid Loss: 0.818903
# Epoch:    7 | Train Loss: 1.093014 | Valid Loss: 0.998149
# Epoch:    8 | Train Loss: 1.087425 | Valid Loss: 1.191816
# Epoch:    9 | Train Loss: 1.081430 | Valid Loss: 1.285880
# Epoch:   10 | Train Loss: 1.073589 | Valid Loss: 1.348312
# Epoch:   11 | Train Loss: 1.062878 | Valid Loss: 1.510247
# Epoch:   12 | Train Loss: 1.064452 | Valid Loss: 1.437099
# Epoch:   13 | Train Loss: 1.057335 | Valid Loss: 1.520199
# Epoch:   14 | Train Loss: 1.048792 | Valid Loss: 1.477627
# Epoch:   15 | Train Loss: 1.030784 | Valid Loss: 1.726137
# Epoch:   16 | Train Loss: 1.021485 | Valid Loss: 1.750628
# Epoch:   17 | Train Loss: 1.001786 | Valid Loss: 1.891245
# Epoch:   18 | Train Loss: 0.979573 | Valid Loss: 2.272016
# Epoch:   19 | Train Loss: 0.970721 | Valid Loss: 2.492987
# Epoch:   20 | Train Loss: 0.965066 | Valid Loss: 2.682468
# Epoch:   21 | Train Loss: 0.959576 | Valid Loss: 2.819969
# Epoch:   22 | Train Loss: 0.973470 | Valid Loss: 2.240415
# Epoch:   23 | Train Loss: 0.961743 | Valid Loss: 2.224576
# Epoch:   24 | Train Loss: 0.982653 | Valid Loss: 2.551225
# Epoch:   25 | Train Loss: 0.950610 | Valid Loss: 2.002960
# Epoch:   26 | Train Loss: 0.935810 | Valid Loss: 2.505301
# Epoch:   27 | Train Loss: 0.930967 | Valid Loss: 2.549472
# Epoch:   28 | Train Loss: 0.934428 | Valid Loss: 2.759473
# Epoch:   29 | Train Loss: 0.909942 | Valid Loss: 2.967711
# Epoch:   30 | Train Loss: 0.896465 | Valid Loss: 3.457041
# Epoch:   31 | Train Loss: 0.887321 | Valid Loss: 3.427109
# Epoch:   32 | Train Loss: 0.881237 | Valid Loss: 3.955464
# Epoch:   33 | Train Loss: 0.871370 | Valid Loss: 3.860532
# Epoch:   34 | Train Loss: 0.859450 | Valid Loss: 4.076275
# Epoch:   35 | Train Loss: 0.851592 | Valid Loss: 4.254459
# Evaluation MSE: 6.634663
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.137207 | Valid Loss: 0.832006
# Epoch:    2 | Train Loss: 1.134122 | Valid Loss: 0.832842
# Epoch:    3 | Train Loss: 1.131640 | Valid Loss: 0.833867
# Epoch:    4 | Train Loss: 1.129528 | Valid Loss: 0.835172
# Epoch:    5 | Train Loss: 1.127705 | Valid Loss: 0.836766
# Epoch:    6 | Train Loss: 1.126110 | Valid Loss: 0.838512
# Epoch:    7 | Train Loss: 1.124706 | Valid Loss: 0.840212
# Epoch:    8 | Train Loss: 1.123480 | Valid Loss: 0.841720
# Epoch:    9 | Train Loss: 1.122422 | Valid Loss: 0.842868
# Epoch:   10 | Train Loss: 1.121511 | Valid Loss: 0.843539
# Epoch:   11 | Train Loss: 1.120844 | Valid Loss: 0.843720
# Epoch:   12 | Train Loss: 1.120481 | Valid Loss: 0.843770
# Epoch:   13 | Train Loss: 1.120139 | Valid Loss: 0.843749
# Epoch:   14 | Train Loss: 1.119813 | Valid Loss: 0.843694
# Epoch:   15 | Train Loss: 1.119500 | Valid Loss: 0.843625
# Epoch:   16 | Train Loss: 1.119198 | Valid Loss: 0.843550
# Epoch:   17 | Train Loss: 1.118906 | Valid Loss: 0.843471
# Epoch:   18 | Train Loss: 1.118623 | Valid Loss: 0.843390
# Epoch:   19 | Train Loss: 1.118347 | Valid Loss: 0.843307
# Epoch:   20 | Train Loss: 1.118120 | Valid Loss: 0.843171
# Epoch:   21 | Train Loss: 1.117988 | Valid Loss: 0.843087
# Epoch:   22 | Train Loss: 1.117857 | Valid Loss: 0.843025
# Epoch:   23 | Train Loss: 1.117727 | Valid Loss: 0.842973
# Epoch:   24 | Train Loss: 1.117599 | Valid Loss: 0.842925
# Epoch:   25 | Train Loss: 1.117472 | Valid Loss: 0.842877
# Epoch:   26 | Train Loss: 1.117345 | Valid Loss: 0.842829
# Epoch:   27 | Train Loss: 1.117220 | Valid Loss: 0.842781
# Epoch:   28 | Train Loss: 1.117096 | Valid Loss: 0.842732
# Epoch:   29 | Train Loss: 1.116991 | Valid Loss: 0.842661
# Epoch:   30 | Train Loss: 1.116930 | Valid Loss: 0.842616
# Epoch:   31 | Train Loss: 1.116868 | Valid Loss: 0.842582
# Evaluation MSE: 1.158627
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.221027 | Valid Loss: 0.875495
# Epoch:    2 | Train Loss: 1.172264 | Valid Loss: 0.830496
# Epoch:    3 | Train Loss: 1.141354 | Valid Loss: 0.860104
# Epoch:    4 | Train Loss: 1.120747 | Valid Loss: 0.810653
# Epoch:    5 | Train Loss: 1.139387 | Valid Loss: 0.811273
# Epoch:    6 | Train Loss: 1.105556 | Valid Loss: 1.203873
# Epoch:    7 | Train Loss: 1.092666 | Valid Loss: 1.517324
# Epoch:    8 | Train Loss: 1.071095 | Valid Loss: 1.995481
# Epoch:    9 | Train Loss: 1.034832 | Valid Loss: 3.273653
# Epoch:   10 | Train Loss: 1.011685 | Valid Loss: 6.613288
# Epoch:   11 | Train Loss: 0.987061 | Valid Loss: 10.738847
# Epoch:   12 | Train Loss: 0.969656 | Valid Loss: 20.582469
# Epoch:   13 | Train Loss: 0.939124 | Valid Loss: 29.871910
# Epoch:   14 | Train Loss: 0.918462 | Valid Loss: 48.754889
# Epoch:   15 | Train Loss: 0.880602 | Valid Loss: 66.563221
# Epoch:   16 | Train Loss: 0.837906 | Valid Loss: 121.132016
# Epoch:   17 | Train Loss: 0.817816 | Valid Loss: 169.962091
# Epoch:   18 | Train Loss: 0.786798 | Valid Loss: 194.419019
# Epoch:   19 | Train Loss: 0.742402 | Valid Loss: 172.707118
# Epoch:   20 | Train Loss: 0.769798 | Valid Loss: 193.014860
# Epoch:   21 | Train Loss: 0.738785 | Valid Loss: 181.045844
# Epoch:   22 | Train Loss: 0.774691 | Valid Loss: 261.442348
# Epoch:   23 | Train Loss: 0.790509 | Valid Loss: 280.423371
# Epoch:   24 | Train Loss: 0.685128 | Valid Loss: 265.928451
# Epoch:   25 | Train Loss: 0.638013 | Valid Loss: 266.174571
# Epoch:   26 | Train Loss: 0.603531 | Valid Loss: 280.085657
# Epoch:   27 | Train Loss: 0.576492 | Valid Loss: 348.804967
# Epoch:   28 | Train Loss: 0.552439 | Valid Loss: 370.028406
# Epoch:   29 | Train Loss: 0.535291 | Valid Loss: 431.389987
# Epoch:   30 | Train Loss: 0.517162 | Valid Loss: 419.688810
# Epoch:   31 | Train Loss: 0.505251 | Valid Loss: 473.989024
# Epoch:   32 | Train Loss: 0.489621 | Valid Loss: 461.261038
# Epoch:   33 | Train Loss: 0.468837 | Valid Loss: 451.094746
# Epoch:   34 | Train Loss: 0.450683 | Valid Loss: 482.213377
# Evaluation MSE: 1058.141846
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.127414 | Valid Loss: 0.824883
# Epoch:    2 | Train Loss: 1.108479 | Valid Loss: 0.817927
# Epoch:    3 | Train Loss: 1.087542 | Valid Loss: 0.808595
# Epoch:    4 | Train Loss: 1.061462 | Valid Loss: 0.796421
# Epoch:    5 | Train Loss: 1.029515 | Valid Loss: 0.809367
# Epoch:    6 | Train Loss: 1.024801 | Valid Loss: 0.912282
# Epoch:    7 | Train Loss: 1.045138 | Valid Loss: 0.959784
# Epoch:    8 | Train Loss: 1.016105 | Valid Loss: 1.350562
# Epoch:    9 | Train Loss: 0.982507 | Valid Loss: 1.735251
# Epoch:   10 | Train Loss: 0.947481 | Valid Loss: 2.950293
# Epoch:   11 | Train Loss: 0.937676 | Valid Loss: 3.459946
# Epoch:   12 | Train Loss: 0.970596 | Valid Loss: 4.375618
# Epoch:   13 | Train Loss: 0.910070 | Valid Loss: 5.928084
# Epoch:   14 | Train Loss: 0.887076 | Valid Loss: 5.211782
# Epoch:   15 | Train Loss: 0.844129 | Valid Loss: 5.072709
# Epoch:   16 | Train Loss: 0.808231 | Valid Loss: 6.057415
# Epoch:   17 | Train Loss: 0.779048 | Valid Loss: 7.266352
# Epoch:   18 | Train Loss: 0.761087 | Valid Loss: 7.284976
# Epoch:   19 | Train Loss: 0.780292 | Valid Loss: 8.863815
# Epoch:   20 | Train Loss: 0.741416 | Valid Loss: 7.401652
# Epoch:   21 | Train Loss: 0.726217 | Valid Loss: 6.947143
# Epoch:   22 | Train Loss: 0.708652 | Valid Loss: 7.174258
# Epoch:   23 | Train Loss: 0.699725 | Valid Loss: 7.155447
# Epoch:   24 | Train Loss: 0.648857 | Valid Loss: 7.135286
# Epoch:   25 | Train Loss: 0.631112 | Valid Loss: 7.688333
# Epoch:   26 | Train Loss: 0.611208 | Valid Loss: 8.270832
# Epoch:   27 | Train Loss: 0.595016 | Valid Loss: 8.831343
# Epoch:   28 | Train Loss: 0.580967 | Valid Loss: 8.984685
# Epoch:   29 | Train Loss: 0.566406 | Valid Loss: 9.805992
# Epoch:   30 | Train Loss: 0.562839 | Valid Loss: 9.974221
# Epoch:   31 | Train Loss: 0.568002 | Valid Loss: 10.170032
# Epoch:   32 | Train Loss: 0.572657 | Valid Loss: 9.760892
# Epoch:   33 | Train Loss: 0.541665 | Valid Loss: 10.297154
# Epoch:   34 | Train Loss: 0.527155 | Valid Loss: 10.162788
# Evaluation MSE: 45.239933
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.108455 | Valid Loss: 0.842733
# Epoch:    2 | Train Loss: 1.095856 | Valid Loss: 0.934942
# Epoch:    3 | Train Loss: 1.085433 | Valid Loss: 0.912787
# Epoch:    4 | Train Loss: 1.075932 | Valid Loss: 0.883878
# Epoch:    5 | Train Loss: 1.066758 | Valid Loss: 0.859364
# Epoch:    6 | Train Loss: 1.056475 | Valid Loss: 0.845089
# Epoch:    7 | Train Loss: 1.043822 | Valid Loss: 0.844908
# Epoch:    8 | Train Loss: 1.029183 | Valid Loss: 0.850937
# Epoch:    9 | Train Loss: 1.014581 | Valid Loss: 0.871343
# Epoch:   10 | Train Loss: 0.999518 | Valid Loss: 0.912249
# Epoch:   11 | Train Loss: 0.980170 | Valid Loss: 0.940525
# Epoch:   12 | Train Loss: 0.970692 | Valid Loss: 0.946480
# Epoch:   13 | Train Loss: 0.962439 | Valid Loss: 0.995475
# Epoch:   14 | Train Loss: 0.958155 | Valid Loss: 0.966203
# Epoch:   15 | Train Loss: 0.948871 | Valid Loss: 1.019916
# Epoch:   16 | Train Loss: 0.947701 | Valid Loss: 0.983754
# Epoch:   17 | Train Loss: 0.938265 | Valid Loss: 1.027691
# Epoch:   18 | Train Loss: 0.937114 | Valid Loss: 1.024491
# Epoch:   19 | Train Loss: 0.929739 | Valid Loss: 1.043187
# Epoch:   20 | Train Loss: 0.930970 | Valid Loss: 1.071617
# Epoch:   21 | Train Loss: 0.924878 | Valid Loss: 1.055593
# Epoch:   22 | Train Loss: 0.905020 | Valid Loss: 1.100528
# Epoch:   23 | Train Loss: 0.895477 | Valid Loss: 1.161534
# Epoch:   24 | Train Loss: 0.889690 | Valid Loss: 1.218766
# Epoch:   25 | Train Loss: 0.885148 | Valid Loss: 1.254798
# Epoch:   26 | Train Loss: 0.880117 | Valid Loss: 1.283438
# Epoch:   27 | Train Loss: 0.875325 | Valid Loss: 1.326354
# Epoch:   28 | Train Loss: 0.871650 | Valid Loss: 1.371368
# Epoch:   29 | Train Loss: 0.865814 | Valid Loss: 1.366988
# Epoch:   30 | Train Loss: 0.862151 | Valid Loss: 1.378687
# Epoch:   31 | Train Loss: 0.859462 | Valid Loss: 1.402250
# Evaluation MSE: 4.329191
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.124895 | Valid Loss: 0.830111
# Epoch:    2 | Train Loss: 1.122961 | Valid Loss: 0.828431
# Epoch:    3 | Train Loss: 1.121562 | Valid Loss: 0.825786
# Epoch:    4 | Train Loss: 1.120291 | Valid Loss: 0.825811
# Epoch:    5 | Train Loss: 1.119125 | Valid Loss: 0.830204
# Epoch:    6 | Train Loss: 1.118018 | Valid Loss: 0.832268
# Epoch:    7 | Train Loss: 1.116921 | Valid Loss: 0.832155
# Epoch:    8 | Train Loss: 1.115821 | Valid Loss: 0.831625
# Epoch:    9 | Train Loss: 1.114733 | Valid Loss: 0.831134
# Epoch:   10 | Train Loss: 1.113643 | Valid Loss: 0.830912
# Epoch:   11 | Train Loss: 1.112546 | Valid Loss: 0.830971
# Epoch:   12 | Train Loss: 1.111443 | Valid Loss: 0.831280
# Epoch:   13 | Train Loss: 1.110450 | Valid Loss: 0.831497
# Epoch:   14 | Train Loss: 1.109861 | Valid Loss: 0.831865
# Epoch:   15 | Train Loss: 1.109265 | Valid Loss: 0.832258
# Epoch:   16 | Train Loss: 1.108669 | Valid Loss: 0.832704
# Epoch:   17 | Train Loss: 1.108073 | Valid Loss: 0.833213
# Epoch:   18 | Train Loss: 1.107478 | Valid Loss: 0.833712
# Epoch:   19 | Train Loss: 1.106880 | Valid Loss: 0.834233
# Epoch:   20 | Train Loss: 1.106277 | Valid Loss: 0.834811
# Epoch:   21 | Train Loss: 1.105672 | Valid Loss: 0.835371
# Epoch:   22 | Train Loss: 1.105131 | Valid Loss: 0.835535
# Epoch:   23 | Train Loss: 1.104828 | Valid Loss: 0.835814
# Epoch:   24 | Train Loss: 1.104528 | Valid Loss: 0.836104
# Epoch:   25 | Train Loss: 1.104230 | Valid Loss: 0.836379
# Epoch:   26 | Train Loss: 1.103933 | Valid Loss: 0.836711
# Epoch:   27 | Train Loss: 1.103634 | Valid Loss: 0.837090
# Epoch:   28 | Train Loss: 1.103339 | Valid Loss: 0.837453
# Epoch:   29 | Train Loss: 1.103041 | Valid Loss: 0.837821
# Epoch:   30 | Train Loss: 1.102735 | Valid Loss: 0.838165
# Epoch:   31 | Train Loss: 1.102470 | Valid Loss: 0.838306
# Epoch:   32 | Train Loss: 1.102322 | Valid Loss: 0.838474
# Epoch:   33 | Train Loss: 1.102172 | Valid Loss: 0.838652
# Evaluation MSE: 1.188431
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.198599 | Valid Loss: 0.822823
# Epoch:    2 | Train Loss: 1.139532 | Valid Loss: 0.831375
# Epoch:    3 | Train Loss: 1.125865 | Valid Loss: 0.823616
# Epoch:    4 | Train Loss: 1.118765 | Valid Loss: 0.817548
# Epoch:    5 | Train Loss: 1.126895 | Valid Loss: 0.809121
# Epoch:    6 | Train Loss: 1.106710 | Valid Loss: 0.840169
# Epoch:    7 | Train Loss: 1.111269 | Valid Loss: 0.805568
# Epoch:    8 | Train Loss: 1.087168 | Valid Loss: 0.871696
# Epoch:    9 | Train Loss: 1.087787 | Valid Loss: 0.894002
# Epoch:   10 | Train Loss: 1.083118 | Valid Loss: 0.903856
# Epoch:   11 | Train Loss: 1.047601 | Valid Loss: 1.186910
# Epoch:   12 | Train Loss: 1.057983 | Valid Loss: 0.997859
# Epoch:   13 | Train Loss: 1.036167 | Valid Loss: 1.785986
# Epoch:   14 | Train Loss: 0.986785 | Valid Loss: 3.116284
# Epoch:   15 | Train Loss: 0.965328 | Valid Loss: 2.121148
# Epoch:   16 | Train Loss: 0.965965 | Valid Loss: 2.064403
# Epoch:   17 | Train Loss: 0.942212 | Valid Loss: 1.958584
# Epoch:   18 | Train Loss: 0.953547 | Valid Loss: 1.321259
# Epoch:   19 | Train Loss: 0.805112 | Valid Loss: 1.825551
# Epoch:   20 | Train Loss: 0.698071 | Valid Loss: 2.087804
# Epoch:   21 | Train Loss: 0.646076 | Valid Loss: 2.298579
# Epoch:   22 | Train Loss: 0.644703 | Valid Loss: 2.606178
# Epoch:   23 | Train Loss: 0.603284 | Valid Loss: 2.243776
# Epoch:   24 | Train Loss: 0.596258 | Valid Loss: 2.652735
# Epoch:   25 | Train Loss: 0.614253 | Valid Loss: 2.361101
# Epoch:   26 | Train Loss: 0.539259 | Valid Loss: 1.801258
# Epoch:   27 | Train Loss: 0.473928 | Valid Loss: 2.256204
# Epoch:   28 | Train Loss: 0.377877 | Valid Loss: 2.436884
# Epoch:   29 | Train Loss: 0.334190 | Valid Loss: 2.568830
# Epoch:   30 | Train Loss: 0.295742 | Valid Loss: 2.749853
# Epoch:   31 | Train Loss: 0.268947 | Valid Loss: 2.722753
# Epoch:   32 | Train Loss: 0.249129 | Valid Loss: 2.835704
# Epoch:   33 | Train Loss: 0.238273 | Valid Loss: 2.830835
# Epoch:   34 | Train Loss: 0.222758 | Valid Loss: 3.037745
# Epoch:   35 | Train Loss: 0.203748 | Valid Loss: 2.990469
# Epoch:   36 | Train Loss: 0.179567 | Valid Loss: 3.012108
# Epoch:   37 | Train Loss: 0.166828 | Valid Loss: 3.053936
# Evaluation MSE: 4.474254
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.125487 | Valid Loss: 0.839024
# Epoch:    2 | Train Loss: 1.114497 | Valid Loss: 0.831700
# Epoch:    3 | Train Loss: 1.105744 | Valid Loss: 0.830672
# Epoch:    4 | Train Loss: 1.096469 | Valid Loss: 0.791679
# Epoch:    5 | Train Loss: 1.090064 | Valid Loss: 0.849337
# Epoch:    6 | Train Loss: 1.082137 | Valid Loss: 0.873720
# Epoch:    7 | Train Loss: 1.067318 | Valid Loss: 1.111316
# Epoch:    8 | Train Loss: 1.054790 | Valid Loss: 1.221025
# Epoch:    9 | Train Loss: 1.045960 | Valid Loss: 2.435911
# Epoch:   10 | Train Loss: 1.024512 | Valid Loss: 2.681382
# Epoch:   11 | Train Loss: 1.047913 | Valid Loss: 5.746823
# Epoch:   12 | Train Loss: 1.050561 | Valid Loss: 5.261453
# Epoch:   13 | Train Loss: 1.036778 | Valid Loss: 4.212968
# Epoch:   14 | Train Loss: 1.013614 | Valid Loss: 7.219898
# Epoch:   15 | Train Loss: 0.971646 | Valid Loss: 17.041929
# Epoch:   16 | Train Loss: 0.950560 | Valid Loss: 25.219906
# Epoch:   17 | Train Loss: 0.947561 | Valid Loss: 41.831216
# Epoch:   18 | Train Loss: 0.948279 | Valid Loss: 24.792440
# Epoch:   19 | Train Loss: 0.945756 | Valid Loss: 17.853860
# Epoch:   20 | Train Loss: 0.929305 | Valid Loss: 41.209599
# Epoch:   21 | Train Loss: 0.905934 | Valid Loss: 106.114905
# Epoch:   22 | Train Loss: 0.884163 | Valid Loss: 86.390273
# Epoch:   23 | Train Loss: 0.881780 | Valid Loss: 121.861284
# Epoch:   24 | Train Loss: 0.865965 | Valid Loss: 220.354018
# Epoch:   25 | Train Loss: 0.848744 | Valid Loss: 218.908898
# Epoch:   26 | Train Loss: 0.853458 | Valid Loss: 261.139953
# Epoch:   27 | Train Loss: 0.826188 | Valid Loss: 284.744507
# Epoch:   28 | Train Loss: 0.819661 | Valid Loss: 327.337980
# Epoch:   29 | Train Loss: 0.815189 | Valid Loss: 348.477737
# Epoch:   30 | Train Loss: 0.815527 | Valid Loss: 334.271075
# Epoch:   31 | Train Loss: 0.817400 | Valid Loss: 316.989135
# Epoch:   32 | Train Loss: 0.799279 | Valid Loss: 330.131295
# Epoch:   33 | Train Loss: 0.783783 | Valid Loss: 353.422343
# Epoch:   34 | Train Loss: 0.778114 | Valid Loss: 347.206260
# Evaluation MSE: 372.665466
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.112994 | Valid Loss: 0.833810
# Epoch:    2 | Train Loss: 1.077261 | Valid Loss: 0.860036
# Epoch:    3 | Train Loss: 1.052787 | Valid Loss: 0.952521
# Epoch:    4 | Train Loss: 1.028994 | Valid Loss: 1.078434
# Epoch:    5 | Train Loss: 1.006594 | Valid Loss: 1.288634
# Epoch:    6 | Train Loss: 0.980877 | Valid Loss: 1.468203
# Epoch:    7 | Train Loss: 0.957803 | Valid Loss: 1.920917
# Epoch:    8 | Train Loss: 0.924432 | Valid Loss: 2.405414
# Epoch:    9 | Train Loss: 0.899833 | Valid Loss: 2.775059
# Epoch:   10 | Train Loss: 0.870423 | Valid Loss: 3.119419
# Epoch:   11 | Train Loss: 0.843656 | Valid Loss: 4.407284
# Epoch:   12 | Train Loss: 0.819426 | Valid Loss: 4.260938
# Epoch:   13 | Train Loss: 0.795143 | Valid Loss: 4.803509
# Epoch:   14 | Train Loss: 0.773898 | Valid Loss: 5.161649
# Epoch:   15 | Train Loss: 0.754926 | Valid Loss: 5.926782
# Epoch:   16 | Train Loss: 0.727635 | Valid Loss: 6.542677
# Epoch:   17 | Train Loss: 0.712541 | Valid Loss: 6.602794
# Epoch:   18 | Train Loss: 0.699949 | Valid Loss: 7.560765
# Epoch:   19 | Train Loss: 0.683127 | Valid Loss: 7.389346
# Epoch:   20 | Train Loss: 0.664322 | Valid Loss: 8.013228
# Epoch:   21 | Train Loss: 0.659357 | Valid Loss: 7.899553
# Epoch:   22 | Train Loss: 0.630566 | Valid Loss: 8.535660
# Epoch:   23 | Train Loss: 0.627359 | Valid Loss: 8.707973
# Epoch:   24 | Train Loss: 0.616971 | Valid Loss: 8.356313
# Epoch:   25 | Train Loss: 0.613533 | Valid Loss: 9.405574
# Epoch:   26 | Train Loss: 0.594565 | Valid Loss: 9.267384
# Epoch:   27 | Train Loss: 0.588192 | Valid Loss: 9.385948
# Epoch:   28 | Train Loss: 0.576610 | Valid Loss: 10.132539
# Epoch:   29 | Train Loss: 0.572842 | Valid Loss: 9.844243
# Epoch:   30 | Train Loss: 0.555850 | Valid Loss: 10.321327
# Epoch:   31 | Train Loss: 0.548577 | Valid Loss: 10.448105
# Evaluation MSE: 47.501842
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.143645 | Valid Loss: 0.936911
# Epoch:    2 | Train Loss: 1.121501 | Valid Loss: 1.014824
# Epoch:    3 | Train Loss: 1.112225 | Valid Loss: 1.300203
# Epoch:    4 | Train Loss: 1.114233 | Valid Loss: 22.070515
# Epoch:    5 | Train Loss: 1.110582 | Valid Loss: 62.355183
# Epoch:    6 | Train Loss: 1.109470 | Valid Loss: 22.968676
# Epoch:    7 | Train Loss: 1.110696 | Valid Loss: 135.574704
# Epoch:    8 | Train Loss: 1.124657 | Valid Loss: 4.488888
# Epoch:    9 | Train Loss: 1.119939 | Valid Loss: 0.830814
# Epoch:   10 | Train Loss: 1.125361 | Valid Loss: 0.828317
# Epoch:   11 | Train Loss: 1.121106 | Valid Loss: 28.753211
# Epoch:   12 | Train Loss: 1.125258 | Valid Loss: 0.982015
# Epoch:   13 | Train Loss: 1.125490 | Valid Loss: 1.126826
# Epoch:   14 | Train Loss: 1.125120 | Valid Loss: 0.839448
# Epoch:   15 | Train Loss: 1.124924 | Valid Loss: 0.835424
# Epoch:   16 | Train Loss: 1.124832 | Valid Loss: 0.835473
# Epoch:   17 | Train Loss: 1.124757 | Valid Loss: 0.835570
# Epoch:   18 | Train Loss: 1.124711 | Valid Loss: 0.835668
# Epoch:   19 | Train Loss: 1.124673 | Valid Loss: 0.835745
# Epoch:   20 | Train Loss: 1.124132 | Valid Loss: 0.836126
# Epoch:   21 | Train Loss: 1.124118 | Valid Loss: 0.836459
# Epoch:   22 | Train Loss: 1.124109 | Valid Loss: 0.836494
# Epoch:   23 | Train Loss: 1.124107 | Valid Loss: 0.836488
# Epoch:   24 | Train Loss: 1.124105 | Valid Loss: 0.836486
# Epoch:   25 | Train Loss: 1.124104 | Valid Loss: 0.836487
# Epoch:   26 | Train Loss: 1.124102 | Valid Loss: 0.836488
# Epoch:   27 | Train Loss: 1.124101 | Valid Loss: 0.836490
# Epoch:   28 | Train Loss: 1.124099 | Valid Loss: 0.836492
# Epoch:   29 | Train Loss: 1.123867 | Valid Loss: 0.836544
# Epoch:   30 | Train Loss: 1.123867 | Valid Loss: 0.836637
# Epoch:   31 | Train Loss: 1.123866 | Valid Loss: 0.836685
# Epoch:   32 | Train Loss: 1.123866 | Valid Loss: 0.836705
# Epoch:   33 | Train Loss: 1.123866 | Valid Loss: 0.836715
# Epoch:   34 | Train Loss: 1.123866 | Valid Loss: 0.836717
# Epoch:   35 | Train Loss: 1.123866 | Valid Loss: 0.836719
# Epoch:   36 | Train Loss: 1.123866 | Valid Loss: 0.836718
# Epoch:   37 | Train Loss: 1.123866 | Valid Loss: 0.836721
# Epoch:   38 | Train Loss: 1.123754 | Valid Loss: 0.836735
# Epoch:   39 | Train Loss: 1.123756 | Valid Loss: 0.836747
# Epoch:   40 | Train Loss: 1.123755 | Valid Loss: 0.836764
# Evaluation MSE: 1.164964
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.124897 | Valid Loss: 0.814526
# Epoch:    2 | Train Loss: 1.098790 | Valid Loss: 0.859394
# Epoch:    3 | Train Loss: 1.083622 | Valid Loss: 1.446925
# Epoch:    4 | Train Loss: 1.093276 | Valid Loss: 0.792111
# Epoch:    5 | Train Loss: 1.121013 | Valid Loss: 4.661675
# Epoch:    6 | Train Loss: 1.096724 | Valid Loss: 12.047885
# Epoch:    7 | Train Loss: 1.083135 | Valid Loss: 26.405951
# Epoch:    8 | Train Loss: 1.074042 | Valid Loss: 37.024982
# Epoch:    9 | Train Loss: 1.068035 | Valid Loss: 35.315393
# Epoch:   10 | Train Loss: 1.057009 | Valid Loss: 16.441245
# Epoch:   11 | Train Loss: 1.042306 | Valid Loss: 11.984995
# Epoch:   12 | Train Loss: 1.048464 | Valid Loss: 13.315174
# Epoch:   13 | Train Loss: 1.033176 | Valid Loss: 4.490842
# Epoch:   14 | Train Loss: 1.017394 | Valid Loss: 3.480591
# Epoch:   15 | Train Loss: 1.018453 | Valid Loss: 5.875656
# Epoch:   16 | Train Loss: 0.979333 | Valid Loss: 2.432095
# Epoch:   17 | Train Loss: 0.969261 | Valid Loss: 7.185219
# Epoch:   18 | Train Loss: 0.965076 | Valid Loss: 12.312011
# Epoch:   19 | Train Loss: 0.930741 | Valid Loss: 7.031534
# Epoch:   20 | Train Loss: 0.902359 | Valid Loss: 7.181731
# Epoch:   21 | Train Loss: 0.887123 | Valid Loss: 7.408806
# Epoch:   22 | Train Loss: 0.868930 | Valid Loss: 21.696455
# Epoch:   23 | Train Loss: 0.834619 | Valid Loss: 32.281500
# Epoch:   24 | Train Loss: 0.778060 | Valid Loss: 21.025892
# Epoch:   25 | Train Loss: 0.743693 | Valid Loss: 21.177488
# Epoch:   26 | Train Loss: 0.710812 | Valid Loss: 24.952229
# Epoch:   27 | Train Loss: 0.698419 | Valid Loss: 20.495961
# Epoch:   28 | Train Loss: 0.673469 | Valid Loss: 29.553423
# Epoch:   29 | Train Loss: 0.661356 | Valid Loss: 11.548159
# Epoch:   30 | Train Loss: 0.619769 | Valid Loss: 14.646823
# Epoch:   31 | Train Loss: 0.604067 | Valid Loss: 16.810349
# Epoch:   32 | Train Loss: 0.569986 | Valid Loss: 9.478023
# Epoch:   33 | Train Loss: 0.521027 | Valid Loss: 20.271613
# Epoch:   34 | Train Loss: 0.498610 | Valid Loss: 13.871991
# Evaluation MSE: 74.326813
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.126841 | Valid Loss: 0.831660
# Epoch:    2 | Train Loss: 1.108362 | Valid Loss: 0.831638
# Epoch:    3 | Train Loss: 1.098835 | Valid Loss: 0.830664
# Epoch:    4 | Train Loss: 1.091414 | Valid Loss: 0.828241
# Epoch:    5 | Train Loss: 1.084903 | Valid Loss: 0.823625
# Epoch:    6 | Train Loss: 1.078792 | Valid Loss: 0.815870
# Epoch:    7 | Train Loss: 1.073004 | Valid Loss: 0.805084
# Epoch:    8 | Train Loss: 1.067257 | Valid Loss: 0.795424
# Epoch:    9 | Train Loss: 1.061742 | Valid Loss: 0.800879
# Epoch:   10 | Train Loss: 1.056047 | Valid Loss: 0.855277
# Epoch:   11 | Train Loss: 1.050493 | Valid Loss: 1.005140
# Epoch:   12 | Train Loss: 1.044666 | Valid Loss: 1.276044
# Epoch:   13 | Train Loss: 1.038923 | Valid Loss: 1.635293
# Epoch:   14 | Train Loss: 1.032975 | Valid Loss: 2.010925
# Epoch:   15 | Train Loss: 1.026929 | Valid Loss: 2.373914
# Epoch:   16 | Train Loss: 1.021129 | Valid Loss: 2.734384
# Epoch:   17 | Train Loss: 1.014829 | Valid Loss: 3.086260
# Epoch:   18 | Train Loss: 1.008812 | Valid Loss: 3.328875
# Epoch:   19 | Train Loss: 1.005728 | Valid Loss: 3.586802
# Epoch:   20 | Train Loss: 1.002524 | Valid Loss: 3.763582
# Epoch:   21 | Train Loss: 0.999259 | Valid Loss: 3.975603
# Epoch:   22 | Train Loss: 0.996272 | Valid Loss: 4.188916
# Epoch:   23 | Train Loss: 0.993153 | Valid Loss: 4.410296
# Epoch:   24 | Train Loss: 0.989948 | Valid Loss: 4.638522
# Epoch:   25 | Train Loss: 0.986932 | Valid Loss: 4.858981
# Epoch:   26 | Train Loss: 0.983788 | Valid Loss: 5.118563
# Epoch:   27 | Train Loss: 0.980818 | Valid Loss: 5.255509
# Epoch:   28 | Train Loss: 0.979099 | Valid Loss: 5.409223
# Epoch:   29 | Train Loss: 0.977518 | Valid Loss: 5.549927
# Epoch:   30 | Train Loss: 0.975938 | Valid Loss: 5.689616
# Epoch:   31 | Train Loss: 0.974398 | Valid Loss: 5.812922
# Epoch:   32 | Train Loss: 0.972825 | Valid Loss: 5.950367
# Epoch:   33 | Train Loss: 0.971286 | Valid Loss: 6.094611
# Epoch:   34 | Train Loss: 0.969722 | Valid Loss: 6.216146
# Epoch:   35 | Train Loss: 0.968238 | Valid Loss: 6.379269
# Epoch:   36 | Train Loss: 0.966695 | Valid Loss: 6.450294
# Epoch:   37 | Train Loss: 0.965887 | Valid Loss: 6.527348
# Epoch:   38 | Train Loss: 0.965068 | Valid Loss: 6.600815
# Evaluation MSE: 14.729419
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.134019 | Valid Loss: 0.864798
# Epoch:    2 | Train Loss: 1.120681 | Valid Loss: 0.875206
# Epoch:    3 | Train Loss: 1.102412 | Valid Loss: 1.092766
# Epoch:    4 | Train Loss: 1.095104 | Valid Loss: 1.037369
# Epoch:    5 | Train Loss: 1.072822 | Valid Loss: 1.036742
# Epoch:    6 | Train Loss: 1.051746 | Valid Loss: 1.029200
# Epoch:    7 | Train Loss: 1.038910 | Valid Loss: 1.273134
# Epoch:    8 | Train Loss: 1.033076 | Valid Loss: 0.879035
# Epoch:    9 | Train Loss: 0.988072 | Valid Loss: 1.825238
# Epoch:   10 | Train Loss: 0.948676 | Valid Loss: 1.059669
# Epoch:   11 | Train Loss: 0.911938 | Valid Loss: 1.301015
# Epoch:   12 | Train Loss: 0.845937 | Valid Loss: 1.614869
# Epoch:   13 | Train Loss: 0.809235 | Valid Loss: 1.574278
# Epoch:   14 | Train Loss: 0.788113 | Valid Loss: 1.898582
# Epoch:   15 | Train Loss: 0.745155 | Valid Loss: 2.314901
# Epoch:   16 | Train Loss: 0.709076 | Valid Loss: 2.074094
# Epoch:   17 | Train Loss: 0.683506 | Valid Loss: 1.948121
# Epoch:   18 | Train Loss: 0.635976 | Valid Loss: 2.473424
# Epoch:   19 | Train Loss: 0.554133 | Valid Loss: 2.759123
# Epoch:   20 | Train Loss: 0.483868 | Valid Loss: 3.414424
# Epoch:   21 | Train Loss: 0.449208 | Valid Loss: 3.043300
# Epoch:   22 | Train Loss: 0.405770 | Valid Loss: 3.491895
# Epoch:   23 | Train Loss: 0.362848 | Valid Loss: 3.851200
# Epoch:   24 | Train Loss: 0.331010 | Valid Loss: 4.102850
# Epoch:   25 | Train Loss: 0.320539 | Valid Loss: 3.790512
# Epoch:   26 | Train Loss: 0.326055 | Valid Loss: 3.936640
# Epoch:   27 | Train Loss: 0.305080 | Valid Loss: 3.950051
# Epoch:   28 | Train Loss: 0.271926 | Valid Loss: 4.016962
# Epoch:   29 | Train Loss: 0.242003 | Valid Loss: 4.215262
# Epoch:   30 | Train Loss: 0.204825 | Valid Loss: 4.371388
# Epoch:   31 | Train Loss: 0.183730 | Valid Loss: 4.587238
# Evaluation MSE: 5.523347
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# ...
# Epoch:   35 | Train Loss: 0.829053 | Valid Loss: 9.430752
# Epoch:   36 | Train Loss: 0.826818 | Valid Loss: 9.596424
# Evaluation MSE: 22.887924
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.124984 | Valid Loss: 0.836718
# Epoch:    2 | Train Loss: 1.114833 | Valid Loss: 0.838902
# Epoch:    3 | Train Loss: 1.110151 | Valid Loss: 0.827727
# Epoch:    4 | Train Loss: 1.108970 | Valid Loss: 0.808993
# Epoch:    5 | Train Loss: 1.104415 | Valid Loss: 0.804233
# Epoch:    6 | Train Loss: 1.094862 | Valid Loss: 0.802014
# Epoch:    7 | Train Loss: 1.091474 | Valid Loss: 0.808303
# Epoch:    8 | Train Loss: 1.078274 | Valid Loss: 0.857857
# Epoch:    9 | Train Loss: 1.063079 | Valid Loss: 0.898183
# Epoch:   10 | Train Loss: 1.062594 | Valid Loss: 0.895224
# Epoch:   11 | Train Loss: 1.060976 | Valid Loss: 0.853956
# Epoch:   12 | Train Loss: 1.064091 | Valid Loss: 0.874026
# Epoch:   13 | Train Loss: 1.056403 | Valid Loss: 0.878450
# Epoch:   14 | Train Loss: 1.033660 | Valid Loss: 0.993029
# Epoch:   15 | Train Loss: 1.011970 | Valid Loss: 0.967569
# Epoch:   16 | Train Loss: 1.015880 | Valid Loss: 1.101865
# Epoch:   17 | Train Loss: 0.983136 | Valid Loss: 1.270770
# Epoch:   18 | Train Loss: 0.971421 | Valid Loss: 1.478859
# Epoch:   19 | Train Loss: 0.980406 | Valid Loss: 1.125149
# Epoch:   20 | Train Loss: 0.996243 | Valid Loss: 1.261023
# Epoch:   21 | Train Loss: 0.975851 | Valid Loss: 1.205755
# Epoch:   22 | Train Loss: 0.947358 | Valid Loss: 1.334928
# Epoch:   23 | Train Loss: 0.956299 | Valid Loss: 1.208417
# Epoch:   24 | Train Loss: 0.959939 | Valid Loss: 1.273599
# Epoch:   25 | Train Loss: 0.940871 | Valid Loss: 1.401910
# Epoch:   26 | Train Loss: 0.910598 | Valid Loss: 1.402401
# Epoch:   27 | Train Loss: 0.900622 | Valid Loss: 1.550496
# Epoch:   28 | Train Loss: 0.889418 | Valid Loss: 1.722945
# Epoch:   29 | Train Loss: 0.890599 | Valid Loss: 1.649195
# Epoch:   30 | Train Loss: 0.887280 | Valid Loss: 1.661169
# Epoch:   31 | Train Loss: 0.889630 | Valid Loss: 1.667069
# Epoch:   32 | Train Loss: 0.884364 | Valid Loss: 1.650090
# Epoch:   33 | Train Loss: 0.880503 | Valid Loss: 1.692509
# Epoch:   34 | Train Loss: 0.870447 | Valid Loss: 1.695317
# Epoch:   35 | Train Loss: 0.849279 | Valid Loss: 1.792560
# Epoch:   36 | Train Loss: 0.837712 | Valid Loss: 1.918370
# Evaluation MSE: 2.045419
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.162449 | Valid Loss: 1.125799
# Epoch:    2 | Train Loss: 1.126844 | Valid Loss: 0.945662
# Epoch:    3 | Train Loss: 1.114581 | Valid Loss: 12.501769
# Epoch:    4 | Train Loss: 1.094205 | Valid Loss: 141.457233
# Epoch:    5 | Train Loss: 1.085092 | Valid Loss: 204.940523
# Epoch:    6 | Train Loss: 1.076519 | Valid Loss: 116.679947
# Epoch:    7 | Train Loss: 1.047950 | Valid Loss: 124.584336
# Epoch:    8 | Train Loss: 1.065904 | Valid Loss: 110.690682
# Epoch:    9 | Train Loss: 1.064255 | Valid Loss: 51.250448
# Epoch:   10 | Train Loss: 1.053291 | Valid Loss: 109.456320
# Epoch:   11 | Train Loss: 1.019814 | Valid Loss: 116.426594
# Epoch:   12 | Train Loss: 0.962565 | Valid Loss: 41.256193
# Epoch:   13 | Train Loss: 0.915570 | Valid Loss: 43.196023
# Epoch:   14 | Train Loss: 0.894579 | Valid Loss: 54.516909
# Epoch:   15 | Train Loss: 0.902221 | Valid Loss: 66.772038
# Epoch:   16 | Train Loss: 0.845504 | Valid Loss: 16.658643
# Epoch:   17 | Train Loss: 0.816659 | Valid Loss: 32.439292
# Epoch:   18 | Train Loss: 0.764860 | Valid Loss: 43.020500
# Epoch:   19 | Train Loss: 0.717540 | Valid Loss: 32.956562
# Epoch:   20 | Train Loss: 0.674710 | Valid Loss: 48.759458
# Epoch:   21 | Train Loss: 0.653341 | Valid Loss: 48.391047
# Epoch:   22 | Train Loss: 0.564655 | Valid Loss: 31.196979
# Epoch:   23 | Train Loss: 0.499334 | Valid Loss: 34.524258
# Epoch:   24 | Train Loss: 0.458192 | Valid Loss: 46.489066
# Epoch:   25 | Train Loss: 0.437758 | Valid Loss: 29.368708
# Epoch:   26 | Train Loss: 0.417722 | Valid Loss: 40.322641
# Epoch:   27 | Train Loss: 0.388886 | Valid Loss: 30.239411
# Epoch:   28 | Train Loss: 0.367046 | Valid Loss: 33.940370
# Epoch:   29 | Train Loss: 0.351179 | Valid Loss: 30.182858
# Epoch:   30 | Train Loss: 0.327757 | Valid Loss: 25.494444
# Epoch:   31 | Train Loss: 0.269421 | Valid Loss: 22.106154
# Epoch:   32 | Train Loss: 0.237233 | Valid Loss: 25.803163
# Evaluation MSE: 221.386734
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.131777 | Valid Loss: 0.829817
# Epoch:    2 | Train Loss: 1.104361 | Valid Loss: 0.818299
# Epoch:    3 | Train Loss: 1.090721 | Valid Loss: 0.803560
# Epoch:    4 | Train Loss: 1.080321 | Valid Loss: 0.797626
# Epoch:    5 | Train Loss: 1.071265 | Valid Loss: 0.818569
# Epoch:    6 | Train Loss: 1.056580 | Valid Loss: 0.873745
# Epoch:    7 | Train Loss: 1.041313 | Valid Loss: 0.971053
# Epoch:    8 | Train Loss: 1.025611 | Valid Loss: 1.111921
# Epoch:    9 | Train Loss: 1.016094 | Valid Loss: 1.261400
# Epoch:   10 | Train Loss: 1.003474 | Valid Loss: 1.200181
# Epoch:   11 | Train Loss: 0.994438 | Valid Loss: 1.227746
# Epoch:   12 | Train Loss: 1.026044 | Valid Loss: 1.380089
# Epoch:   13 | Train Loss: 1.009731 | Valid Loss: 1.263420
# Epoch:   14 | Train Loss: 0.969262 | Valid Loss: 1.234173
# Epoch:   15 | Train Loss: 0.935384 | Valid Loss: 1.249433
# Epoch:   16 | Train Loss: 0.914843 | Valid Loss: 1.298181
# Epoch:   17 | Train Loss: 0.897699 | Valid Loss: 1.363855
# Epoch:   18 | Train Loss: 0.881386 | Valid Loss: 1.435961
# Epoch:   19 | Train Loss: 0.865753 | Valid Loss: 1.539799
# Epoch:   20 | Train Loss: 0.850262 | Valid Loss: 1.606680
# Epoch:   21 | Train Loss: 0.837054 | Valid Loss: 1.693609
# Epoch:   22 | Train Loss: 0.824646 | Valid Loss: 1.770140
# Epoch:   23 | Train Loss: 0.817180 | Valid Loss: 1.819559
# Epoch:   24 | Train Loss: 0.815363 | Valid Loss: 1.868078
# Epoch:   25 | Train Loss: 0.794746 | Valid Loss: 1.851149
# Epoch:   26 | Train Loss: 0.781923 | Valid Loss: 1.923004
# Epoch:   27 | Train Loss: 0.771471 | Valid Loss: 1.939990
# Epoch:   28 | Train Loss: 0.761223 | Valid Loss: 1.992727
# Epoch:   29 | Train Loss: 0.752501 | Valid Loss: 2.008831
# Epoch:   30 | Train Loss: 0.744554 | Valid Loss: 2.094184
# Epoch:   31 | Train Loss: 0.736089 | Valid Loss: 2.079915
# Epoch:   32 | Train Loss: 0.725329 | Valid Loss: 2.168025
# Epoch:   33 | Train Loss: 0.718143 | Valid Loss: 2.159155
# Epoch:   34 | Train Loss: 0.712143 | Valid Loss: 2.160423
# Evaluation MSE: 3.597800
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.236416 | Valid Loss: 0.810727
# Epoch:    2 | Train Loss: 1.132715 | Valid Loss: 0.817986
# Epoch:    3 | Train Loss: 1.134965 | Valid Loss: 0.822349
# Epoch:    4 | Train Loss: 1.131468 | Valid Loss: 0.834585
# Epoch:    5 | Train Loss: 1.130230 | Valid Loss: 0.828177
# Epoch:    6 | Train Loss: 1.130437 | Valid Loss: 0.843436
# Epoch:    7 | Train Loss: 1.131187 | Valid Loss: 1.025771
# Epoch:    8 | Train Loss: 1.128721 | Valid Loss: 1.241980
# Epoch:    9 | Train Loss: 1.120689 | Valid Loss: 1.158529
# Epoch:   10 | Train Loss: 1.116273 | Valid Loss: 1.246614
# Epoch:   11 | Train Loss: 1.130584 | Valid Loss: 1.800440
# Epoch:   12 | Train Loss: 1.122861 | Valid Loss: 1.355068
# Epoch:   13 | Train Loss: 1.115869 | Valid Loss: 1.500353
# Epoch:   14 | Train Loss: 1.108322 | Valid Loss: 3.377821
# Epoch:   15 | Train Loss: 1.117104 | Valid Loss: 6.714881
# Epoch:   16 | Train Loss: 1.092448 | Valid Loss: 1.803456
# Epoch:   17 | Train Loss: 1.124778 | Valid Loss: 1.410247
# Epoch:   18 | Train Loss: 1.124942 | Valid Loss: 1.211555
# Epoch:   19 | Train Loss: 1.109321 | Valid Loss: 1.086591
# Epoch:   20 | Train Loss: 1.087365 | Valid Loss: 5.824908
# Epoch:   21 | Train Loss: 1.058564 | Valid Loss: 20.119528
# Epoch:   22 | Train Loss: 1.044841 | Valid Loss: 34.345492
# Epoch:   23 | Train Loss: 1.040176 | Valid Loss: 9.605764
# Epoch:   24 | Train Loss: 1.052538 | Valid Loss: 2.051296
# Epoch:   25 | Train Loss: 1.040760 | Valid Loss: 4.083076
# Epoch:   26 | Train Loss: 1.041970 | Valid Loss: 1.718504
# Epoch:   27 | Train Loss: 1.054864 | Valid Loss: 14.023224
# Epoch:   28 | Train Loss: 1.044026 | Valid Loss: 2.908488
# Epoch:   29 | Train Loss: 1.045819 | Valid Loss: 3.007668
# Epoch:   30 | Train Loss: 1.027259 | Valid Loss: 3.338111
# Epoch:   31 | Train Loss: 1.011849 | Valid Loss: 4.533402
# Evaluation MSE: 5.900746
# --------------------------------------------------
#
# Training Started
# --------------------------------------------------
# Epoch:    1 | Train Loss: 1.147363 | Valid Loss: 0.842684
# Epoch:    2 | Train Loss: 1.134208 | Valid Loss: 3.520783
# Epoch:    3 | Train Loss: 1.133519 | Valid Loss: 4.322369
# Epoch:    4 | Train Loss: 1.133601 | Valid Loss: 4.391355
# Epoch:    5 | Train Loss: 1.133655 | Valid Loss: 4.296431
# Epoch:    6 | Train Loss: 1.133685 | Valid Loss: 4.099832
# Epoch:    7 | Train Loss: 1.133704 | Valid Loss: 3.849761
# Epoch:    8 | Train Loss: 1.133719 | Valid Loss: 4.155752
# Epoch:    9 | Train Loss: 1.133727 | Valid Loss: 3.939253
# Epoch:   10 | Train Loss: 1.133735 | Valid Loss: 3.554351
# Epoch:   11 | Train Loss: 1.128443 | Valid Loss: 3.399491
# Epoch:   12 | Train Loss: 1.128852 | Valid Loss: 3.227962
# Epoch:   13 | Train Loss: 1.128865 | Valid Loss: 3.062348
# Epoch:   14 | Train Loss: 1.128871 | Valid Loss: 2.903731
# Epoch:   15 | Train Loss: 1.128878 | Valid Loss: 2.751686
# Epoch:   16 | Train Loss: 1.128884 | Valid Loss: 2.605743
# Epoch:   17 | Train Loss: 1.128890 | Valid Loss: 2.465498
# Epoch:   18 | Train Loss: 1.128895 | Valid Loss: 2.330044
# Epoch:   19 | Train Loss: 1.128899 | Valid Loss: 2.198821
# Epoch:   20 | Train Loss: 1.127265 | Valid Loss: 2.126346
# Epoch:   21 | Train Loss: 1.127107 | Valid Loss: 2.063408
# Epoch:   22 | Train Loss: 1.127090 | Valid Loss: 2.001746
# Epoch:   23 | Train Loss: 1.127099 | Valid Loss: 1.941380
# Epoch:   24 | Train Loss: 1.127107 | Valid Loss: 1.882617
# Epoch:   25 | Train Loss: 1.127114 | Valid Loss: 1.825792
# Epoch:   26 | Train Loss: 1.127121 | Valid Loss: 1.771237
# Epoch:   27 | Train Loss: 1.127127 | Valid Loss: 1.719072
# Epoch:   28 | Train Loss: 1.127133 | Valid Loss: 1.669399
# Epoch:   29 | Train Loss: 1.125815 | Valid Loss: 1.642692
# Epoch:   30 | Train Loss: 1.125344 | Valid Loss: 1.619429
# Epoch:   31 | Train Loss: 1.125356 | Valid Loss: 1.596697
# Evaluation MSE: 9.177484
# --------------------------------------------------
# 100%|██████████| 50/50 [24:07<00:00, 28.95s/trial, best loss: 1.1586271524429321]
#
# ==================================================
# Optimization Results:
# ==================================================
# Best evaluation MSE: 1.1586
#
# Best parameters:
# batch_size: 256
# dropout_rate: 0.10423895013417002
# hidden_size: 16
# lr: 0.00014889681974569586
# max_epochs: 1000
# nonlin: Tanh()
# num_layers: 2
# seq_length: 5
# use_residual: True
# weight_decay: 0.0453416774723117
#
# Final Test MSE: 0.5014

# %%
from sklearn.metrics import r2_score, mean_squared_error
# Evaluate the model on the test set
net = best_model

# Get predictions on the test data
y_pred_test = net.predict(X_test_seq)

# Calculate the R2 score and MSE for the test data
test_mse = mean_squared_error(y_test_seq, y_pred_test)
test_r2 = r2_score(y_test_seq, y_pred_test)

print(f"Test MSE: {test_mse:.2f}")
print(f"Test R2: {test_r2:.2f}")

# Detach tensors and convert to numpy arrays if needed
y_pred_test = y_pred_test if isinstance(y_pred_test, np.ndarray) else y_pred_test.detach().numpy()
y_test_seq = y_test_seq if isinstance(y_test_seq, np.ndarray) else y_test_seq.detach().numpy()

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test_seq, y_pred_test, alpha=0.5)
plt.title('Predicted vs. True Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.plot([y_test_seq.min(), y_test_seq.max()], [y_test_seq.min(), y_test_seq.max()], 'k--', lw=3)  # Line showing perfect predictions
plt.grid(True)
plt.show()

print(net.history)

history = net.history

# Extract training and validation MSE from the history
train_mse = [h['train_loss'] for h in history]
valid_mse = [h['valid_loss'] for h in history if 'valid_loss' in h]

plt.figure(figsize=(10, 6))
plt.plot(train_mse, label='Training MSE', marker='o')
plt.plot(valid_mse, label='Validation MSE', marker='o')
plt.title('MSE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Print best hyperparameters again for reference
print("\n" + "="*50)
print("Best Hyperparameters:")
print("="*50)
for param, value in best_trial['result']['params'].items():
    print(f"{param}: {value}")
# Out:
# Test MSE: 0.51
# Test R2: -0.03
# [{'batches': [{'train_loss': 0.2585054636001587, 'train_batch_size': 64}, {'train_loss': 2.2686920166015625, 'train_batch_size': 64}, {'train_loss': 1.0173578262329102, 'train_batch_size': 64}, {'train_loss': 1.6361939907073975, 'train_batch_size': 64}, {'train_loss': 1.5530595779418945, 'train_batch_size': 64}, {'train_loss': 0.45863980054855347, 'train_batch_size': 64}, {'train_loss': 1.0836224555969238, 'train_batch_size': 64}, {'train_loss': 0.6700301170349121, 'train_batch_size': 64}, {'train_loss': 0.3409739136695862, 'train_batch_size': 64}, {'train_loss': 1.0938591957092285, 'train_batch_size': 64}, {'train_loss': 1.090054988861084, 'train_batch_size': 64}, {'train_loss': 0.8535929918289185, 'train_batch_size': 64}, {'train_loss': 2.374891519546509, 'train_batch_size': 64}, {'train_loss': 2.441230058670044, 'train_batch_size': 64}, {'train_loss': 1.6098144054412842, 'train_batch_size': 64}, {'train_loss': 4.347476005554199, 'train_batch_size': 64}, {'train_loss': 2.78961443901062, 'train_batch_size': 64}, {'train_loss': 0.9579347372055054, 'train_batch_size': 64}, {'train_loss': 1.280853271484375, 'train_batch_size': 64}, {'train_loss': 0.33824431896209717, 'train_batch_size': 64}, {'train_loss': 1.2864679098129272, 'train_batch_size': 64}, {'train_loss': 0.8744522333145142, 'train_batch_size': 64}, {'train_loss': 0.8621245622634888, 'train_batch_size': 64}, {'train_loss': 1.8949787616729736, 'train_batch_size': 64}, {'train_loss': 1.507621169090271, 'train_batch_size': 64}, {'train_loss': 0.8414928317070007, 'train_batch_size': 64}, {'train_loss': 0.6295676827430725, 'train_batch_size': 64}, {'train_loss': 0.6412760615348816, 'train_batch_size': 64}, {'train_loss': 3.4072768688201904, 'train_batch_size': 64}, {'train_loss': 0.4671451449394226, 'train_batch_size': 64}, {'train_loss': 0.7294667959213257, 'train_batch_size': 42}, {'valid_loss': 0.7820966243743896, 'valid_batch_size': 64}, {'valid_loss': 1.3554754257202148, 'valid_batch_size': 64}, {'valid_loss': 0.7112192511558533, 'valid_batch_size': 64}, {'valid_loss': 0.7875586152076721, 'valid_batch_size': 64}, {'valid_loss': 0.4323521852493286, 'valid_batch_size': 16}], 'epoch': 1, 'train_batch_count': 31, 'valid_batch_count': 5, 'dur': 14.74131464958191, 'train_loss': np.float64(1.3490155157571417), 'train_loss_best': True, 'valid_loss': np.float64(0.8810442265342263), 'valid_loss_best': True}, {'batches': [{'train_loss': 0.287365585565567, 'train_batch_size': 64}, {'train_loss': 0.8279902338981628, 'train_batch_size': 64}, {'train_loss': 0.2927258610725403, 'train_batch_size': 64}, {'train_loss': 1.3185042142868042, 'train_batch_size': 64}, {'train_loss': 0.8394200205802917, 'train_batch_size': 64}, {'train_loss': 0.12459339201450348, 'train_batch_size': 64}, {'train_loss': 1.171112060546875, 'train_batch_size': 64}, {'train_loss': 0.3318990170955658, 'train_batch_size': 64}, {'train_loss': 0.18867336213588715, 'train_batch_size': 64}, {'train_loss': 0.9367406368255615, 'train_batch_size': 64}, {'train_loss': 0.8293922543525696, 'train_batch_size': 64}, {'train_loss': 0.9758961796760559, 'train_batch_size': 64}, {'train_loss': 2.304534912109375, 'train_batch_size': 64}, {'train_loss': 2.188383102416992, 'train_batch_size': 64}, {'train_loss': 1.3868741989135742, 'train_batch_size': 64}, {'train_loss': 4.372175216674805, 'train_batch_size': 64}, {'train_loss': 2.9252872467041016, 'train_batch_size': 64}, {'train_loss': 0.9867982864379883, 'train_batch_size': 64}, {'train_loss': 0.9679174423217773, 'train_batch_size': 64}, {'train_loss': 0.4757337272167206, 'train_batch_size': 64}, {'train_loss': 1.3284661769866943, 'train_batch_size': 64}, {'train_loss': 0.7420210242271423, 'train_batch_size': 64}, {'train_loss': 0.7807812094688416, 'train_batch_size': 64}, {'train_loss': 1.9089089632034302, 'train_batch_size': 64}, {'train_loss': 1.5091358423233032, 'train_batch_size': 64}, {'train_loss': 0.981195867061615, 'train_batch_size': 64}, {'train_loss': 0.52967768907547, ...
# ==================================================
# Best Hyperparameters:
# ==================================================
# batch_size: 64
# hidden_size: 512
# lr: 0.005757494025613979
# max_epochs: 1000
# nonlin: GELU(approximate='none')
# num_layers: 5
